# %% [markdown]
# ### Data prep - test data

# %%
#read train data merged VID - b stepping (used for model training)
import pandas as pd
path = "C:/Users/nchong/OneDrive - Intel Corporation/Documents/ML based speckle POC/"
df_train = pd.read_csv(path+"DataPreparation/MergedData_SameVID/SupFeatures_Train.csv")
# print(df_train["SPECKLE"].value_counts())
print(df_train.shape)
# Out:
# (36434, 17)

# %%
#read c stepping data  (to be used as test data)
import pandas as pd
path = "C:/Users/nchong/OneDrive - Intel Corporation/Documents/ML based speckle POC/"
df_test = pd.read_csv(path+"RawData/Latest/Set3/SNR_C0_MERGED_Dataset_ww12.1.csv")

#check for rows with blank delta
import numpy as np
df_test[df_test["DELTA"].isnull()]

#create new column SPECKLE as target
import numpy as np
df_test["SPECKLE"] = np.where(df_test["DELTA"]==0,0,1)
cols = df_test.columns.tolist()
cols = [cols[-1]]+cols[:-1] #move speckle col to the front
df_test = df_test.reindex(columns=cols)

print(df_test["SPECKLE"].value_counts())
print(df_test.shape)
# Out:
# C:\Users\nchong\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (859,860) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 0    54748
# 1       91
# Name: SPECKLE, dtype: int64
# (54839, 3812)

# %%
#remove rows with 100% blanks - 18882 nonspeckle, 57 speckle
blank = pd.read_csv(path+"DataPreparation/Set3/Others/Set3_AllBlankRows.csv")
df_test =  df_test[~df_test["VID"].isin(blank["VID"])]
print(df_test["SPECKLE"].value_counts())
print(df_test.shape)
# Out:
# 0    35866
# 1       34
# Name: SPECKLE, dtype: int64
# (35900, 3812)

# %%
#add in the non blank speckle data
nonblank = pd.read_csv(path+"RawData/Latest/Set3/Set3_AllBlankRows_withfeatures_Speckle.csv")
print(nonblank["SPECKLE"].value_counts())
print(nonblank.shape)
# Out:
# 1    57
# Name: SPECKLE, dtype: int64
# (57, 3678)

# %%
#make the colums equal
df_test = df_test.loc[:,df_test.columns.isin(list(set(df_test.columns).intersection(set(nonblank.columns))))]
nonblank = nonblank.loc[:,nonblank.columns.isin(list(set(df_test.columns).intersection(set(nonblank.columns))))]
print(df_test.shape)
print(nonblank.shape)
# Out:
# (35900, 3528)
# (57, 3528)

# %%
#merge existing data and non blank
df_test = pd.concat([df_test,nonblank]).reset_index(drop=True)
print(df_test.shape)
# Out:
# (35957, 3528)

# %%
print(df_test["SPECKLE"].value_counts())
print(df_test.shape)
# Out:
# 0    35866
# 1       91
# Name: SPECKLE, dtype: int64
# (35957, 3528)

# %%
# missing_fs = list(set(df_test.columns).difference(set(nonblank.columns)))
# missing_fs
# pd.DataFrame(missing_fs).to_csv(path +"missing_fs.csv",index=False)

# %%
#check if there's any overlap in VID in df_test and train -> no overlap in VIDs
df_test[df_test["VID"].isin(df_train["VID"])]
# Out:
# Empty DataFrame
_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_NAC_GBE_SMB_DATA_CPU, SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_NAC_INIT_SX_WAKE_N_CPU, SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_NAC_KR0_TX_DP_0, SIO_L ...
# Index: []
#
# [0 rows x 3528 columns]

# %%
#check if there's any overlap in VID in df_test and train -> no overlap in VIDs
print(set(df_test["VID"]).intersection(set(df_train["VID"])))
# Out:
# set()

# %%
df_test.to_csv(path+"DataPreparation/Set3/Test_Set3.csv",index=False)

# %%
pd.DataFrame(df_test.columns).to_csv(path+"DataPreparation/Set3/columns.csv",index=False)

# %%
import pandas as pd
path = "C:/Users/nchong/OneDrive - Intel Corporation/Documents/ML based speckle POC/"
df_test = pd.read_csv(path+"DataPreparation/Set3/Test_Set3.csv")

# %%
#additional columns to merge with test set 3
df_add =  pd.read_csv(path+"/RawData/Latest/Set3/Test_Set3_SF_Filled_R2.csv")
supporting_fs = ['SORTLOT','SORTLOT7','WAFER', 'XLOC', 'YLOC', 'TEST RESULTS',
       'TEST RESULTS BITS', 'TR_BITS', 'INCOMING', 'INCOMING BITS', 'INC_BITS',
       'OUTGOING', 'OUTGOING BITS', 'OUT_BITS', 'DELTA','IB@6261[CLASSHOT]', 'FB@6261[CLASSHOT]']
df_add = df_add.drop(supporting_fs,axis=1) 
df_add
# Out:
#                  VID  \
# 0      M2LH384800140
# 1      M2LH384800126
# 2      M2LH384800018
# 3      M2LH384800015
# 4      M2LH384800011
# ...              ...
# 35952  M2JF162500004
# 35953  M2R34A3500778
# 35954  M2C6074701403
# 35955  M2C6074700195
# 35956  M26042R600832
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_SDS_SIUP_SICC_VCCADLLOPI_V1@132110  \
# 0                                               0.048690
# 1                                               0.053269
# 2                                               0.047844
# 3                                               0.038054
# 4                                               0.045548
# ...                                                  ...
# 35952                                           0.034558
# 35953                                           0.033266
# 35954                                           0.035325
# 35955                                           0.041888
# 35956                                           0.046113
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_SDS_SIUP_SICC_VCCADLLOPI_V1@132150  \
# 0                                               0.048690
# 1                                               0.053269
# 2                                               0.047844
# 3                                               0.038054
# 4                                               0.045548
# ...                                                  ...
# 35952                                           0.034558
# 35953                                           0.033266
# 35954                                           0.035325
# 35955                                           0.041888
# 35956                                           0.046113
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_SDS_SIUP_SICC_VCCAGSH_CLM_EHV_V1@132110  \
# 0                                               0.019428
# 1                                               0.019549
# 2                                               0.019416
# 3                                               0.020633
# 4                                               0.020411
# ...                                                  ...
# 35952                                           0.017496
# 35953                                           0.017183
# 35954                                           0.020193
# 35955                                           0.019477
# 35956                                           0.018487
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_SDS_SIUP_SICC_VCCAGSH_CLM_EHV_V1@132150  \
# 0                                               0.019428
# 1                                               0.019549
# 2                                               0.019416
# 3                                               0.020633
# 4                                               0.020411
# ...                                                  ...
# 35952                                           0.017496
# 35953                                           0.017183
# 35954                                           0.020193
# 35955                                           0.019477
# 35956                                           0.018487
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_SDS_SIUP_SICC_VCCAOPI_V1@132110  \
# 0                                               0.012401
# 1                                               0.013254
# 2                                               0.009032
# 3                                               0.014327
# 4                                               0.013684
# ...                                                  ...
# 35952                                           0.017709
# 35953                                           0.013053
# 35954                                           0.016930
# 35955                                           0.015365
# 35956                                           0.011999
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_SDS_SIUP_SICC_VCCAOPI_V1@132150  \
# 0                                               0.012401
# 1                                               0.013254
# 2                                               0.009032
# 3                                               0.014327
# 4                                               0.013684
# ...                                                  ...
# 35952                                           0.017709
# 35953                                           0.013053
# 35954                                           0.016930
# 35955                                           0.015365
# 35956                                           0.011999
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_SDS_SIUP_SICC_VCCAPLLOPI_FAD_DIGICKSI0_V1@132110  \
# 0                                                0.00819
# 1                                                0.00194
# 2                                                0.00170
# 3                                                0.00279
# 4                                                0.00453
# ...                                                  ...
# 35952                                            0.00214
# 35953                                            0.01020
# 35954                                            0.00348
# 35955                                            0.00358
# 35956                                            0.00212
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_SDS_SIUP_SICC_VCCAPLLOPI_FAD_DIGICKSI0_V1@132150  \
# 0                                                0.00819
# 1                                                0.00194
# 2                                                0.00170
# 3                                                0.00279
# 4                                                0.00453
# ...                                                  ...
# 35952                                            0.00214
# 35953                                            0.01020
# 35954                                            0.00348
# 35955                                            0.00358
# 35956                                            0.00212
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_SDS_SIUP_SICC_VCCCORE_M01_V1@132110  \
# 0                                                0.05880
# 1                                                0.07600
# 2                                                0.00929
# 3                                                0.01930
# 4                                                0.02140
# ...                                                  ...
# 35952                                            0.02420
# 35953                                            0.01440
# 35954                                            0.07710
# 35955                                            0.07630
# 35956                                            0.08550
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 35952  ...
# 35953  ...
# 35954  ...
# 35955  ...
# 35956  ...
#
#        TPI_VCC::CONT_X_SCREEN_K_SDTBEGIN_X_X_X_X_VCCADTL_VCCIN_EHV_LC_ADTL@132150  \
# 0                                               -0.00369
# 1                                               -0.00349
# 2                                               -0.00359
# 3                                               -0.00373
# 4                                               -0.00342
# ...                                                  ...
# 35952                                           -0.00353
# 35953                                           -0.00342
# 35954                                           -0.00336
# 35955                                           -0.00385
# 35956                                           -0.00373
#
#        TPI_VCC::CONT_X_SCREEN_K_SDTBEGIN_X_X_X_X_VCCADTL_VCCVNN_HC_ADTL@132110  \
# 0                                               -0.00578
# 1                                               -0.00630
# 2                                               -0.00704
# 3                                               -0.00792
# 4                                               -0.00708
# ...                                                  ...
# 35952                                           -0.00679
# 35953                                           -0.00644
# 35954                                           -0.00762
# 35955                                           -0.00697
# 35956                                           -0.00619
#
#        TPI_VCC::CONT_X_SCREEN_K_SDTBEGIN_X_X_X_X_VCCADTL_VCCVNN_HC_ADTL@132150  \
# 0                                               -0.00578
# 1                                               -0.00630
# 2                                               -0.00704
# 3                                               -0.00792
# 4                                               -0.00708
# ...                                                  ...
# 35952                                           -0.00679
# 35953                                           -0.00644
# 35954                                           -0.00762
# 35955                                           -0.00697
# 35956                                           -0.00619
#
#        PTH_POWER::POWER_X_SCREEN_K_BEGIN_X_X_X_X_CALC_PP_PT_CDYN_VCCDDRD_0P95_2667@132110  \
# 0                                               1.272511
# 1                                               1.268205
# 2                                               1.255658
# 3                                               1.302891
# 4                                               1.282997
# ...                                                  ...
# 35952                                           1.229967
# 35953                                           1.239396
# 35954                                           1.265706
# 35955                                           1.252055
# 35956                                           1.217424
#
#        PTH_POWER::POWER_X_SCREEN_K_BEGIN_X_X_X_X_CALC_PP_PT_CDYN_VCCSA_0P95@132110  \
# 0                                               3.132166
# 1                                               3.135231
# 2                                               3.124614
# 3                                               3.209428
# 4                                               3.218449
# ...                                                  ...
# 35952                                           3.030096
# 35953                                           3.061690
# 35954                                           3.133549
# 35955                                           3.089399
# 35956                                           3.025815
#
#        PTH_POWER::POWER_X_SCREEN_K_BEGIN_X_X_X_X_CALC_PP_PT_CDYN_VCCVNN_0P95_F2@132110  \
# 0                                               5.312574
# 1                                               5.329291
# 2                                               5.389388
# 3                                               5.481777
# 4                                               5.352074
# ...                                                  ...
# 35952                                           5.211700
# 35953                                           5.148924
# 35954                                           5.316001
# 35955                                           5.283192
# 35956                                           5.183960
#
#        PTH_POWER_SDT::POWER_X_ANAMEA_E_SDTBEGIN_X_X_V2_X_FULLCHIPSICC_PP_SICC_VCCRAM_M012345@132150  \
# 0                                               0.571079
# 1                                               0.544621
# 2                                               0.305387
# 3                                               0.458830
# 4                                               0.520298
# ...                                                  ...
# 35952                                           0.580874
# 35953                                           0.303680
# 35954                                           0.531460
# 35955                                           0.707951
# 35956                                           0.409870
#
#        TPI_VCC::CONT_VCCIOA_HC_E_SDTSTART_X_X_X_MIM_VCCIOA@132150  \
# 0                                               0.000247
# 1                                               0.000261
# 2                                               0.000120
# 3                                               0.000187
# 4                                               0.000142
# ...                                                  ...
# 35952                                           0.000159
# 35953                                           0.000049
# 35954                                           0.000198
# 35955                                           0.000327
# 35956                                           0.000171
#
#        TPI_VCC::CONT_VCCRAMM012345_HC_E_SDTSTART_X_X_X_MIM_VCCRAM_M012345@132150  \
# 0                                               0.000753
# 1                                               0.000579
# 2                                               0.000151
# 3                                               0.000593
# 4                                               0.000090
# ...                                                  ...
# 35952                                           0.000085
# 35953                                          -0.000158
# 35954                                           0.000990
# 35955                                           0.001258
# 35956                                           0.000686
#
#        TPI_VCC::CONT_VCCRAMM012345_HC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_VCCRAM_M012345@132150
# 0                                               0.001752
# 1                                               0.001962
# 2                                               0.000488
# 3                                               0.001056
# 4                                               0.001005
# ...                                                  ...
# 35952                                           0.000587
# 35953                                           0.000222
# 35954                                           0.002147
# 35955                                           0.003401
# 35956                                           0.001564
#
# [35957 rows x 220 columns]

# %%
df_test = pd.merge(df_test,df_add,on='VID')
df_test
# Out:
#        SPECKLE            VID   SORTLOT  WAFER  XLOC  YLOC  IB@6261[CLASSHOT]  \
# 0            0  M2LH384800140  N1333240    833    -5    -3                  1
# 1            0  M2LH384800126  N1333240    833    -2     7                  1
# 2            0  M2LH384800018  N1331070    866     2    -9                  1
# 3            0  M2LH384800015  N1331070    866     2    -2                  1
# 4            0  M2LH384800011  N1331070    866    -6    -2                  1
# ...        ...            ...       ...    ...   ...   ...                ...
# 35952        1  M2JF162500004  N1352350    707     1     5                  1
# 35953        1  M2R34A3500778  N1345270    505    -3    -5                  1
# 35954        1  M2C6074701403  N1345550    353     2     0                  1
# 35955        1  M2C6074700195  N1352350    708     0     1                  1
# 35956        1  M26042R600832  N1345550    322     5    -6                  1
#
#        FB@6261[CLASSHOT] TEST RESULTS  TEST RESULTS BITS  ...  \
# 0                    101      B000000                  0  ...
# 1                    101      B000000                  0  ...
# 2                    101      B000000                  0  ...
# 3                    101      B000000                  0  ...
# 4                    101      B000000                  0  ...
# ...                  ...          ...                ...  ...
# 35952                101      B010000              10000  ...
# 35953                101      B001000               1000  ...
# 35954                101      B001000               1000  ...
# 35955                101      B000001                  1  ...
# 35956                101      B001000               1000  ...
#
#        TPI_VCC::CONT_X_SCREEN_K_SDTBEGIN_X_X_X_X_VCCADTL_VCCIN_EHV_LC_ADTL@132150  \
# 0                                               -0.00369
# 1                                               -0.00349
# 2                                               -0.00359
# 3                                               -0.00373
# 4                                               -0.00342
# ...                                                  ...
# 35952                                           -0.00353
# 35953                                           -0.00342
# 35954                                           -0.00336
# 35955                                           -0.00385
# 35956                                           -0.00373
#
#       TPI_VCC::CONT_X_SCREEN_K_SDTBEGIN_X_X_X_X_VCCADTL_VCCVNN_HC_ADTL@132110  \
# 0                                               -0.00578
# 1                                               -0.00630
# 2                                               -0.00704
# 3                                               -0.00792
# 4                                               -0.00708
# ...                                                  ...
# 35952                                           -0.00679
# 35953                                           -0.00644
# 35954                                           -0.00762
# 35955                                           -0.00697
# 35956                                           -0.00619
#
#        TPI_VCC::CONT_X_SCREEN_K_SDTBEGIN_X_X_X_X_VCCADTL_VCCVNN_HC_ADTL@132150  \
# 0                                               -0.00578
# 1                                               -0.00630
# 2                                               -0.00704
# 3                                               -0.00792
# 4                                               -0.00708
# ...                                                  ...
# 35952                                           -0.00679
# 35953                                           -0.00644
# 35954                                           -0.00762
# 35955                                           -0.00697
# 35956                                           -0.00619
#
#        PTH_POWER::POWER_X_SCREEN_K_BEGIN_X_X_X_X_CALC_PP_PT_CDYN_VCCDDRD_0P95_2667@132110  \
# 0                                               1.272511
# 1                                               1.268205
# 2                                               1.255658
# 3                                               1.302891
# 4                                               1.282997
# ...                                                  ...
# 35952                                           1.229967
# 35953                                           1.239396
# 35954                                           1.265706
# 35955                                           1.252055
# 35956                                           1.217424
#
#       PTH_POWER::POWER_X_SCREEN_K_BEGIN_X_X_X_X_CALC_PP_PT_CDYN_VCCSA_0P95@132110  \
# 0                                               3.132166
# 1                                               3.135231
# 2                                               3.124614
# 3                                               3.209428
# 4                                               3.218449
# ...                                                  ...
# 35952                                           3.030096
# 35953                                           3.061690
# 35954                                           3.133549
# 35955                                           3.089399
# 35956                                           3.025815
#
#        PTH_POWER::POWER_X_SCREEN_K_BEGIN_X_X_X_X_CALC_PP_PT_CDYN_VCCVNN_0P95_F2@132110  \
# 0                                               5.312574
# 1                                               5.329291
# 2                                               5.389388
# 3                                               5.481777
# 4                                               5.352074
# ...                                                  ...
# 35952                                           5.211700
# 35953                                           5.148924
# 35954                                           5.316001
# 35955                                           5.283192
# 35956                                           5.183960
#
#        PTH_POWER_SDT::POWER_X_ANAMEA_E_SDTBEGIN_X_X_V2_X_FULLCHIPSICC_PP_SICC_VCCRAM_M012345@132150  \
# 0                                               0.571079
# 1                                               0.544621
# 2                                               0.305387
# 3                                               0.458830
# 4                                               0.520298
# ...                                                  ...
# 35952                                           0.580874
# 35953                                           0.303680
# 35954                                           0.531460
# 35955                                           0.707951
# 35956                                           0.409870
#
#        TPI_VCC::CONT_VCCIOA_HC_E_SDTSTART_X_X_X_MIM_VCCIOA@132150  \
# 0                                               0.000247
# 1                                               0.000261
# 2                                               0.000120
# 3                                               0.000187
# 4                                               0.000142
# ...                                                  ...
# 35952                                           0.000159
# 35953                                           0.000049
# 35954                                           0.000198
# 35955                                           0.000327
# 35956                                           0.000171
#
#        TPI_VCC::CONT_VCCRAMM012345_HC_E_SDTSTART_X_X_X_MIM_VCCRAM_M012345@132150  \
# 0                                               0.000753
# 1                                               0.000579
# 2                                               0.000151
# 3                                               0.000593
# 4                                               0.000090
# ...                                                  ...
# 35952                                           0.000085
# 35953                                          -0.000158
# 35954                                           0.000990
# 35955                                           0.001258
# 35956                                           0.000686
#
#        TPI_VCC::CONT_VCCRAMM012345_HC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_VCCRAM_M012345@132150
# 0                                               0.001752
# 1                                               0.001962
# 2                                               0.000488
# 3                                               0.001056
# 4                                               0.001005
# ...                                                  ...
# 35952                                           0.000587
# 35953                                           0.000222
# 35954                                           0.002147
# 35955                                           0.003401
# 35956                                           0.001564
#
# [35957 rows x 3747 columns]

# %%
df_test.to_csv(path +"DataPreparation/Set3/Test_Set3.csv",index=False)

# %%
import pandas as pd
path = "C:/Users/nchong/OneDrive - Intel Corporation/Documents/ML based speckle POC/"
df_test = pd.read_csv(path+"DataPreparation/Set3/Test_Set3.csv")
df_test
# Out:
#        SPECKLE            VID   SORTLOT  WAFER  XLOC  YLOC  IB@6261[CLASSHOT]  \
# 0            0  M2LH384800140  N1333240    833    -5    -3                  1
# 1            0  M2LH384800126  N1333240    833    -2     7                  1
# 2            0  M2LH384800018  N1331070    866     2    -9                  1
# 3            0  M2LH384800015  N1331070    866     2    -2                  1
# 4            0  M2LH384800011  N1331070    866    -6    -2                  1
# ...        ...            ...       ...    ...   ...   ...                ...
# 35952        1  M2JF162500004  N1352350    707     1     5                  1
# 35953        1  M2R34A3500778  N1345270    505    -3    -5                  1
# 35954        1  M2C6074701403  N1345550    353     2     0                  1
# 35955        1  M2C6074700195  N1352350    708     0     1                  1
# 35956        1  M26042R600832  N1345550    322     5    -6                  1
#
#        FB@6261[CLASSHOT] TEST RESULTS  TEST RESULTS BITS  ...  \
# 0                    101      B000000                  0  ...
# 1                    101      B000000                  0  ...
# 2                    101      B000000                  0  ...
# 3                    101      B000000                  0  ...
# 4                    101      B000000                  0  ...
# ...                  ...          ...                ...  ...
# 35952                101      B010000              10000  ...
# 35953                101      B001000               1000  ...
# 35954                101      B001000               1000  ...
# 35955                101      B000001                  1  ...
# 35956                101      B001000               1000  ...
#
#        TPI_VCC::CONT_X_SCREEN_K_SDTBEGIN_X_X_X_X_VCCADTL_VCCIN_EHV_LC_ADTL@132150  \
# 0                                               -0.00369
# 1                                               -0.00349
# 2                                               -0.00359
# 3                                               -0.00373
# 4                                               -0.00342
# ...                                                  ...
# 35952                                           -0.00353
# 35953                                           -0.00342
# 35954                                           -0.00336
# 35955                                           -0.00385
# 35956                                           -0.00373
#
#       TPI_VCC::CONT_X_SCREEN_K_SDTBEGIN_X_X_X_X_VCCADTL_VCCVNN_HC_ADTL@132110  \
# 0                                               -0.00578
# 1                                               -0.00630
# 2                                               -0.00704
# 3                                               -0.00792
# 4                                               -0.00708
# ...                                                  ...
# 35952                                           -0.00679
# 35953                                           -0.00644
# 35954                                           -0.00762
# 35955                                           -0.00697
# 35956                                           -0.00619
#
#        TPI_VCC::CONT_X_SCREEN_K_SDTBEGIN_X_X_X_X_VCCADTL_VCCVNN_HC_ADTL@132150  \
# 0                                               -0.00578
# 1                                               -0.00630
# 2                                               -0.00704
# 3                                               -0.00792
# 4                                               -0.00708
# ...                                                  ...
# 35952                                           -0.00679
# 35953                                           -0.00644
# 35954                                           -0.00762
# 35955                                           -0.00697
# 35956                                           -0.00619
#
#        PTH_POWER::POWER_X_SCREEN_K_BEGIN_X_X_X_X_CALC_PP_PT_CDYN_VCCDDRD_0P95_2667@132110  \
# 0                                               1.272511
# 1                                               1.268205
# 2                                               1.255658
# 3                                               1.302891
# 4                                               1.282997
# ...                                                  ...
# 35952                                           1.229967
# 35953                                           1.239396
# 35954                                           1.265706
# 35955                                           1.252055
# 35956                                           1.217424
#
#       PTH_POWER::POWER_X_SCREEN_K_BEGIN_X_X_X_X_CALC_PP_PT_CDYN_VCCSA_0P95@132110  \
# 0                                               3.132166
# 1                                               3.135231
# 2                                               3.124614
# 3                                               3.209428
# 4                                               3.218449
# ...                                                  ...
# 35952                                           3.030096
# 35953                                           3.061690
# 35954                                           3.133549
# 35955                                           3.089399
# 35956                                           3.025815
#
#        PTH_POWER::POWER_X_SCREEN_K_BEGIN_X_X_X_X_CALC_PP_PT_CDYN_VCCVNN_0P95_F2@132110  \
# 0                                               5.312574
# 1                                               5.329291
# 2                                               5.389388
# 3                                               5.481777
# 4                                               5.352074
# ...                                                  ...
# 35952                                           5.211700
# 35953                                           5.148924
# 35954                                           5.316001
# 35955                                           5.283192
# 35956                                           5.183960
#
#        PTH_POWER_SDT::POWER_X_ANAMEA_E_SDTBEGIN_X_X_V2_X_FULLCHIPSICC_PP_SICC_VCCRAM_M012345@132150  \
# 0                                               0.571079
# 1                                               0.544621
# 2                                               0.305387
# 3                                               0.458830
# 4                                               0.520298
# ...                                                  ...
# 35952                                           0.580874
# 35953                                           0.303680
# 35954                                           0.531460
# 35955                                           0.707951
# 35956                                           0.409870
#
#        TPI_VCC::CONT_VCCIOA_HC_E_SDTSTART_X_X_X_MIM_VCCIOA@132150  \
# 0                                               0.000247
# 1                                               0.000261
# 2                                               0.000120
# 3                                               0.000187
# 4                                               0.000142
# ...                                                  ...
# 35952                                           0.000159
# 35953                                           0.000049
# 35954                                           0.000198
# 35955                                           0.000327
# 35956                                           0.000171
#
#        TPI_VCC::CONT_VCCRAMM012345_HC_E_SDTSTART_X_X_X_MIM_VCCRAM_M012345@132150  \
# 0                                               0.000753
# 1                                               0.000579
# 2                                               0.000151
# 3                                               0.000593
# 4                                               0.000090
# ...                                                  ...
# 35952                                           0.000085
# 35953                                          -0.000158
# 35954                                           0.000990
# 35955                                           0.001258
# 35956                                           0.000686
#
#        TPI_VCC::CONT_VCCRAMM012345_HC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_VCCRAM_M012345@132150
# 0                                               0.001752
# 1                                               0.001962
# 2                                               0.000488
# 3                                               0.001056
# 4                                               0.001005
# ...                                                  ...
# 35952                                           0.000587
# 35953                                           0.000222
# 35954                                           0.002147
# 35955                                           0.003401
# 35956                                           0.001564
#
# [35957 rows x 3747 columns]

# %%
#map C0 names to B3 feature names
def featuremapping(df,feature_mapping,old,new):
    """
    df[DataFrame]: data where feature names are to be mapped
    feature_mapping[DataFrame]: feature file that contains the old and new feature names
    old[str]: name of the old feature column
    new[str]: name of the new feature column
    """
    old_col = feature_mapping[old].values.tolist()
    new_col = feature_mapping[new].values.tolist()
  
    df.rename(
        columns={i:j for i,j in zip(new_col,old_col)}, inplace=True
    )
    return df

feature_mapping = pd.read_csv(path+"DataPreparation/Set3/FeatureMapping_C0_B3_Edited.csv")
old = "B3"
new = "C0"
df_test = featuremapping(df_test,feature_mapping,old,new)
df_test.shape
# Out:
# (35957, 3747)

# %%
train = pd.read_csv(path + "/DataPreparation/MergedData_SameVID/TrainData_Corr0.95Rem.csv")
train = train.drop(["SPECKLE"],axis=1)
train.shape
# Out:
# (36434, 671)

# %%
#remove supporting_fs
supporting_fs = ['VID','SORTLOT', 'WAFER', 'XLOC', 'YLOC', 'TEST RESULTS',
       'TEST RESULTS BITS', 'TR_BITS', 'INCOMING', 'INCOMING BITS', 'INC_BITS',
       'OUTGOING', 'OUTGOING BITS', 'OUT_BITS', 'DELTA','IB@6261[CLASSHOT]', 'FB@6261[CLASSHOT]','SPECKLE']
df_test_sf = df_test[supporting_fs] #keep supporting fs of df_test
df_test = df_test.drop(supporting_fs,axis=1)

# %%
df_test = df_test.loc[:,df_test.columns.isin(train.columns)]
df_test
# Out:
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_CATERR_N_CPU  \
# 0                                           1.980000e-06
# 1                                           2.110000e-06
# 2                                           1.240000e-06
# 3                                           1.310000e-06
# 4                                           6.640000e-07
# ...                                                  ...
# 35952                                       2.140000e-06
# 35953                                       9.610000e-07
# 35954                                       1.870000e-06
# 35955                                       3.210000e-06
# 35956                                       7.320000e-07
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_CDF_MSMI_N_CPU  \
# 0                                           1.290000e-06
# 1                                           1.530000e-06
# 2                                           4.960000e-07
# 3                                           5.650000e-07
# 4                                           1.590000e-06
# ...                                                  ...
# 35952                                       2.090000e-06
# 35953                                       2.120000e-06
# 35954                                       2.560000e-06
# 35955                                       1.790000e-06
# 35956                                       2.460000e-06
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_CDF_THERMTRIP_N_CPU  \
# 0                                               0.000003
# 1                                               0.000003
# 2                                               0.000002
# 3                                               0.000002
# 4                                               0.000001
# ...                                                  ...
# 35952                                           0.000002
# 35953                                           0.000002
# 35954                                           0.000001
# 35955                                           0.000001
# 35956                                           0.000002
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_DEBUG_EN_N  \
# 0                                               0.000001
# 1                                               0.000001
# 2                                               0.000002
# 3                                               0.000002
# 4                                               0.000002
# ...                                                  ...
# 35952                                           0.000002
# 35953                                           0.000002
# 35954                                           0.000001
# 35955                                           0.000001
# 35956                                           0.000002
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_EAR_N  \
# 0                                               0.000002
# 1                                               0.000002
# 2                                               0.000002
# 3                                               0.000002
# 4                                               0.000003
# ...                                                  ...
# 35952                                           0.000002
# 35953                                           0.000002
# 35954                                           0.000001
# 35955                                           0.000003
# 35956                                           0.000002
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_ERROR0_N_CPU  \
# 0                                           1.210000e-06
# 1                                           1.610000e-06
# 2                                           7.930000e-07
# 3                                           6.940000e-07
# 4                                           6.710000e-07
# ...                                                  ...
# 35952                                       2.620000e-06
# 35953                                       1.880000e-06
# 35954                                       1.170000e-06
# 35955                                       2.720000e-06
# 35956                                       2.120000e-06
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_ERROR1_N_CPU  \
# 0                                           1.660000e-06
# 1                                           1.630000e-06
# 2                                           7.250000e-07
# 3                                           8.930000e-07
# 4                                           1.250000e-06
# ...                                                  ...
# 35952                                       2.490000e-06
# 35953                                       1.750000e-06
# 35954                                       1.250000e-06
# 35955                                       9.000000e-07
# 35956                                       1.820000e-06
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_ERROR2_N_CPU  \
# 0                                           1.710000e-06
# 1                                           1.840000e-06
# 2                                           1.210000e-06
# 3                                           1.210000e-06
# 4                                           4.200000e-07
# ...                                                  ...
# 35952                                       2.490000e-06
# 35953                                       2.040000e-06
# 35954                                       2.540000e-06
# 35955                                       2.560000e-06
# 35956                                       1.880000e-06
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_FBRK_N_CPU  \
# 0                                           2.460000e-06
# 1                                           2.720000e-06
# 2                                           1.570000e-06
# 3                                           1.640000e-06
# 4                                           1.230000e-06
# ...                                                  ...
# 35952                                       9.080000e-07
# 35953                                      -7.930000e-07
# 35954                                       1.050000e-06
# 35955                                       7.480000e-07
# 35956                                      -7.930000e-07
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_FIVR_CLKREF  \
# 0                                               0.000002
# 1                                               0.000002
# 2                                               0.000002
# 3                                               0.000002
# 4                                               0.000003
# ...                                                  ...
# 35952                                           0.000001
# 35953                                           0.000002
# 35954                                           0.000002
# 35955                                           0.000002
# 35956                                           0.000001
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 35952  ...
# 35953  ...
# 35954  ...
# 35955  ...
# 35956  ...
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFUSEHV2_V1_132150  \
# 0                                              -0.001220
# 1                                              -0.001090
# 2                                              -0.000864
# 3                                              -0.000616
# 4                                              -0.001470
# ...                                                  ...
# 35952                                          -0.000793
# 35953                                          -0.001750
# 35954                                          -0.000741
# 35955                                          -0.000771
# 35956                                          -0.002190
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCINF_V1_132110  \
# 0                                               0.061762
# 1                                               0.063405
# 2                                               0.038258
# 3                                               0.048783
# 4                                               0.054818
# ...                                                  ...
# 35952                                           0.059004
# 35953                                           0.039030
# 35954                                           0.058706
# 35955                                           0.057559
# 35956                                           0.055522
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132110  \
# 0                                               0.101282
# 1                                               0.098775
# 2                                               0.100102
# 3                                               0.101898
# 4                                               0.103240
# ...                                                  ...
# 35952                                           0.107691
# 35953                                           0.104464
# 35954                                           0.104824
# 35955                                           0.105340
# 35956                                           0.102586
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132150  \
# 0                                               0.101282
# 1                                               0.098775
# 2                                               0.100102
# 3                                               0.101898
# 4                                               0.103240
# ...                                                  ...
# 35952                                           0.107691
# 35953                                           0.104464
# 35954                                           0.104824
# 35955                                           0.105340
# 35956                                           0.102586
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCRAM_M012345_V1_132110  \
# 0                                               0.129697
# 1                                               0.125215
# 2                                               0.043657
# 3                                               0.090991
# 4                                               0.143294
# ...                                                  ...
# 35952                                           0.141604
# 35953                                           0.059089
# 35954                                           0.104052
# 35955                                           0.138233
# 35956                                           0.046624
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSA_V1_132110  \
# 0                                               0.144388
# 1                                               0.160947
# 2                                               0.128603
# 3                                               0.143191
# 4                                               0.141019
# ...                                                  ...
# 35952                                           0.126801
# 35953                                           0.118446
# 35954                                           0.152348
# 35955                                           0.159376
# 35956                                           0.146967
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSFR_HV_V1_132150  \
# 0                                               0.016616
# 1                                               0.016679
# 2                                               0.017228
# 3                                               0.018593
# 4                                               0.016770
# ...                                                  ...
# 35952                                           0.013791
# 35953                                           0.013602
# 35954                                           0.016198
# 35955                                           0.016566
# 35956                                           0.016198
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCVNN_V1_132110  \
# 0                                               0.370098
# 1                                               0.238482
# 2                                               0.112978
# 3                                               0.208768
# 4                                               0.147160
# ...                                                  ...
# 35952                                           0.217900
# 35953                                           0.232171
# 35954                                           0.446311
# 35955                                           0.304388
# 35956                                           0.263493
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCCLM_V1_132150  \
# 0                                               0.298004
# 1                                               0.267327
# 2                                               0.143718
# 3                                               0.258959
# 4                                               0.584695
# ...                                                  ...
# 35952                                           0.395498
# 35953                                           0.266982
# 35954                                           0.364429
# 35955                                           0.258331
# 35956                                           0.176275
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCINPMAXQ_V1_132150
# 0                                           8.570000e-06
# 1                                           9.030000e-06
# 2                                          -2.200000e-05
# 3                                          -1.750000e-05
# 4                                          -3.240000e-05
# ...                                                  ...
# 35952                                       7.430000e-06
# 35953                                      -5.380000e-06
# 35954                                      -2.450000e-06
# 35955                                       3.890000e-05
# 35956                                       5.140000e-07
#
# [35957 rows x 671 columns]

# %%
df_test.to_csv(path+"DataPreparation/Set3/Test_Set3_MappedtoB3.csv",index=False)

# %%
df_test_sf.to_csv(path+"DataPreparation/Set3/Test_Set3_MappedtoB3_SF.csv",index=False)

# %%
import pandas as pd
path = "C:/Users/nchong/OneDrive - Intel Corporation/Documents/ML based speckle POC/"
df_test = pd.read_csv(path+"DataPreparation/Set3_TrainValExchange/Test_Set3_MappedtoB3.csv")
df_test_sf = pd.read_csv(path+"DataPreparation/Set3_TrainValExchange/Test_Set3_MappedtoB3_SF.csv")

print(df_test.shape)
print(df_test_sf.shape)
# Out:
# (35957, 672)
# (35957, 17)

# %%
# Check for VID duplicates
def check_duplicates(df):
    """
    Check for duplicates in VID 
    df[DataFrame]: input df    
    """
    if df['VID'].duplicated().any():
        print("There are duplicates in VID")
        df_dup = df[df.duplicated(subset=['VID'])] #get the duplicates in df, returns repeated rows only 
        df= df[df["VID"].isin(df_dup["VID"])] #get all the duplicates in df, returns original + repeated rows 
        return df
    else:
        print("There are no duplicates in VID")
        
check_duplicates(df_test_sf)
# Out:
# There are no duplicates in VID

# %%
print(df_test["SPECKLE"].value_counts())
print(df_test_sf.shape)
print(df_test.shape)
# Out:
# 0    35866
# 1       91
# Name: SPECKLE, dtype: int64
# (35957, 17)
# (35957, 672)

# %%
# check column for nulls
def check_colna(df):
    """
    Check each column for nulls. Returns Feature, total null and % of null for each column
    df[DataFrame]: dataframe
    
    """
    colna_df = pd.DataFrame(columns =["Feature", "Total Null", "% of Null"])
    for col in df.columns: 
        #checking if there is any null in the column

        if df[col].isnull().sum()>0: 
            
            # if null present, total number of null in the column stores here
            total_null = df[col].isnull().sum() 
            new_row = {'Feature':col, 'Total Null':total_null, '% of Null':total_null*100/len(df)}
            #append row to the dataframe
            colna_df = colna_df.append(new_row, ignore_index=True)
            
    colna_df= colna_df.sort_values("% of Null", ascending=False)    
    return colna_df  

# check rows for nulls
def check_rowna(df,supporting_fs):  
    """
    Check each row for nulls.Returns VID, total null and % of null for each row
    df[DataFrame]: dataframe
    supporting_fs[list/None]: all features not used for ML except VID and SPECKLE(target), None - no sf to be removed
    """
    if supporting_fs != None:
        df = df.drop(supporting_fs,axis=1)  
        
    colrow_df = pd.DataFrame(columns =["SPECKLE","VID", "Total Null", "% of Null"])
    for i in df.index: 
        #checking if there is any null in the row
        if df.iloc[i].isnull().sum()>0:             
            # if null present, total number of null in the row stores here
            total_null = df.iloc[i].isnull().sum() 
            new_row = {'SPECKLE':df.iloc[i,0],'VID':df.iloc[i,1], 'Total Null':total_null, '% of Null':round(total_null*100/(len(df.columns)-2),2)}
            #append row to the dataframe
            colrow_df = colrow_df.append(new_row, ignore_index=True)
            
    colrow_df= colrow_df.sort_values("% of Null", ascending=False)    
    return colrow_df

# %%
#check column na
nacol = check_colna(df_test)
display(nacol)
nacol.to_csv(path+"DataPreparation/Set3/NACols.csv",index=False)
# Out:
#                                                Feature Total Null  % of Null
# 101  IDV_0009_NOM1GISO12_FULLDIE_SOC_TALL_0650_MED_...       1547   4.302361
# 139     IDV_0057_HVT1GISO8_FULLDIE_SOC_0950_MED_132110       1547   4.302361
# 129      IDV_0047_NOMNLK12_FULLDIE_SOC_0650_MED_132110       1547   4.302361
# 130      IDV_0047_NOMNLK12_FULLDIE_SOC_0950_MED_132110       1547   4.302361
# 131  IDV_0047_NOMNLK12_FULLDIE_SOC_TALL_0650_MED_13...       1547   4.302361
# ..                                                 ...        ...        ...
# 75   TPI_VCC::CONT_X_SCREEN_E_FINAL_X_X_X_X_SNR_VCC...          2   0.005562
# 74   TPI_VCC::CONT_X_SCREEN_E_FINAL_X_X_X_X_SNR_VCC...          2   0.005562
# 66   TPI_VCC::CONT_X_SCREEN_E_FINAL_X_X_X_X_SNR_VCC...          2   0.005562
# 70   TPI_VCC::CONT_X_SCREEN_E_FINAL_X_X_X_X_SNR_VCC...          2   0.005562
# 72   TPI_VCC::CONT_X_SCREEN_E_FINAL_X_X_X_X_SNR_VCC...          2   0.005562
#
# [203 rows x 3 columns]

# %%
#check row na
supporting_fs = ['SORTLOT', 'WAFER', 'XLOC', 'YLOC', 'TEST RESULTS',
       'TEST RESULTS BITS', 'TR_BITS', 'INCOMING', 'INCOMING BITS', 'INC_BITS',
       'OUTGOING', 'OUTGOING BITS', 'OUT_BITS', 'DELTA','IB@6261[CLASSHOT]', 'FB@6261[CLASSHOT]']

cols = df_test_sf.columns.tolist()
cols = [cols[-1]]+cols[:-1] #move speckle col to the front
df_test_sf = df_test_sf.reindex(columns=cols)
rowna = check_rowna(pd.concat([df_test_sf,df_test],axis=1),supporting_fs)
rowna
# Out:
#             SPECKLE VID Total Null  % of Null
# 464   M2RP360800084   0        151      22.50
# 1095  M1DR882301572   0        151      22.50
# 2032  M1RF993300854   0        151      22.50
# 618   M2RP360801271   0        151      22.50
# 1228  M20C4R1700796   0        151      22.50
# ...             ...  ..        ...        ...
# 2602  M2K06H3100049   0          8       1.19
# 2444  M26Y79U800674   0          7       1.04
# 2308  M2S70J6700185   0          7       1.04
# 2440  M26Y79U800367   0          7       1.04
# 2333  M2T880K301063   0          7       1.04
#
# [2701 rows x 4 columns]

# %%
rowna.to_csv(path+"DataPreparation/Set3/NARows.csv",index=False)

# %%
#NA imputation
def NA_impute(df,imptype):
    """
    Impute NA
    df[DataFrame]:df
    imptype[string]: "mean" to impute data with mean, "median" to impute data with median
    """
    if imptype == "mean":        
        df = df.fillna(df.mean())
    if imptype == "median":
        df = df.fillna(df.median())
    return df

df_test = NA_impute(df_test,imptype="median")

# %%
#check row na
supporting_fs = ['SORTLOT', 'WAFER', 'XLOC', 'YLOC', 'TEST RESULTS',
       'TEST RESULTS BITS', 'TR_BITS', 'INCOMING', 'INCOMING BITS', 'INC_BITS',
       'OUTGOING', 'OUTGOING BITS', 'OUT_BITS', 'DELTA','IB@6261[CLASSHOT]', 'FB@6261[CLASSHOT]']

check_rowna(pd.concat([df_test_sf,df_test],axis=1),supporting_fs)
# Out:
# Empty DataFrame
# Columns: [SPECKLE, VID, Total Null, % of Null]
# Index: []

# %%
df_test.to_csv(path+"DataPreparation/Set3/Test_Set3_NAimputedMedian.csv",index=False)

# %%
print(df_test["SPECKLE"].value_counts())
print(df_test.shape)
# Out:
# 0    35866
# 1       91
# Name: SPECKLE, dtype: int64
# (35957, 672)

# %%
#convert negative columns to positive - except for IDV and HVQK columns
def convert_neg_to_pos(df,cols_to_keep):
    """
    df: dataframe
    cols_to_keep[tuple]: tokens for columns which are not converted to negative
    """
    #df with tokens which are not converted to negative
    df_keep = df[df.columns[df.columns.str.startswith(cols_to_keep)]]
    print("df_keep shape",df_keep.shape)
    
    # Create df_to_convert - drop columns from cols_to_keep
    df_to_convert = df.drop([col for col in df if col.startswith(cols_to_keep)], axis=1)    
    print("df_to_convert shape",df_to_convert.shape)
    
    #Convert negative columns in df_to_convert to positive
    df_positive = df_to_convert.abs()
    print("df_positive shape",df_to_convert.shape)
    
    #check whether there's any negative value left in df_positive
    print("Is there negative value left:",(df_positive < 0).any().any())
    
    #Concatenating df_keep and df_positive along columns
    df = pd.concat([df_keep, df_positive], axis=1)
    print("Shape after converting neg to pos:", df.shape)
    
    return df

df_test = convert_neg_to_pos(df_test,cols_to_keep=("IDV", "HVQK"))
# Out:
# df_keep shape (35957, 201)
# df_to_convert shape (35957, 471)
# df_positive shape (35957, 471)
# Is there negative value left: False
# Shape after converting neg to pos: (35957, 672)

# %%
#Checking column for negative values
def check_col_negative(df,value):
    """
    Check each column for negative values. Returns Feature, total negative values and % of negative values for each column
    df[DataFrame]: dataframe
    
    """
    col_negative_df = pd.DataFrame(columns =["Feature", "Total Negative Values", "% of Negative Values"])
    for col in df.columns: 
        #checking if there is any specific negative value in the column

        if df[col].isin([value]).sum()>0: 
            
            # if specific negative value present, total number of specific negative value in the column stores here
            total_negative = df[col].isin([value]).sum() 
            new_row = {'Feature':col, 'Total Negative Values':total_negative, '% of Negative Values':round(total_negative*100/len(df),2)}
            #append row to the dataframe
            col_negative_df = col_negative_df.append(new_row, ignore_index=True)
            
    col_negative_df = col_negative_df.sort_values("% of Negative Values", ascending=False)    
    return col_negative_df  

print("Checking column for -5555 values")
display(check_col_negative(df_test,value= -5555))
print("Checking column for -555 values")
display(check_col_negative(df_test,value= -555))
print("Checking column for -999 values")
display(check_col_negative(df_test,value= -999))
print("Checking column for -9999 values")
display(check_col_negative(df_test,value = -9999))
# Out:
# Checking column for -5555 values
#                                             Feature Total Negative Values  \
# 42              HVQK_VMIN_POST_SCAN_NAC_CPMC_132110                   699
# 5   HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMCPR_132110                   699
# 6   HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMPKE_132110                   619
# 40              HVQK_VMIN_POST_SCAN_NAC_CPMB_132110                   619
# 54       HVQK_VMIN_POST_SCAN_UNCORE_LLCSFP11_132110                   590
# ..                                              ...                   ...
# 64        HVQK_VMIN_PRE_SCAN_UNCORE_LLCSFP02_132110                    24
# 63        HVQK_VMIN_PRE_SCAN_UNCORE_LLCSFP01_132110                    20
# 66        HVQK_VMIN_PRE_SCAN_UNCORE_LLCSFP12_132110                    22
# 67        HVQK_VMIN_PRE_SCAN_UNCORE_LLCSFP21_132110                    23
# 68        HVQK_VMIN_PRE_SCAN_UNCORE_LLCSFP23_132110                    22
#
#     % of Negative Values
# 42                  1.94
# 5                   1.94
# 6                   1.72
# 40                  1.72
# 54                  1.64
# ..                   ...
# 64                  0.07
# 63                  0.06
# 66                  0.06
# 67                  0.06
# 68                  0.06
#
# [69 rows x 3 columns]
# Checking column for -555 values
# Empty DataFrame
# Columns: [Feature, Total Negative Values, % of Negative Values]
# Index: []
# Checking column for -999 values
#                                               Feature Total Negative Values  \
# 2   IDV_0109_NOM1GISO12_FULLDIE_CORE_TALL_0650_MED...                 12517
# 3   IDV_0113_NOMNDN12_FULLDIE_CORE_TALL_0650_MED_1...                 12517
# 4   IDV_0115_NOMPLK12_FULLDIE_CORE_TALL_0650_MED_1...                 12517
# 5   IDV_0116_SVTPLK12_FULLDIE_CORE_TALL_0650_MED_1...                 12517
# 6   IDV_0118_SVTNDN12_FULLDIE_CORE_TALL_0650_MED_1...                 12517
# 7   IDV_0133_PSVT3GVTO12_FULLDIE_CORE_TALL_0650_ME...                 12517
# 8   IDV_0147_NOMNLK12_FULLDIE_CORE_TALL_0650_MED_1...                 12517
# 9   IDV_0148_SVTNLK12_FULLDIE_CORE_TALL_0650_MED_1...                 12517
# 10      IDV_0148_SVTNLK12_FULLDIE_SOC_0650_MED_132110                    65
# 12       IDV_0234_NOMINVFEM12_FULLDIE_0650_MED_132110                    11
# 11      IDV_0148_SVTNLK12_FULLDIE_SOC_0950_MED_132110                     3
# 0       IDV_0016_SVTPLK12_FULLDIE_SOC_0650_MED_132110                     1
# 1       IDV_0016_SVTPLK12_FULLDIE_SOC_0950_MED_132110                     1
#
#     % of Negative Values
# 2                  34.81
# 3                  34.81
# 4                  34.81
# 5                  34.81
# 6                  34.81
# 7                  34.81
# 8                  34.81
# 9                  34.81
# 10                  0.18
# 12                  0.03
# 11                  0.01
# 0                   0.00
# 1                   0.00
# Checking column for -9999 values
#                               Feature Total Negative Values  \
# 0  HVQK_VMIN_POST_SCAN_NAC_RMN_132110                     1
#
#    % of Negative Values
# 0                   0.0

# %%
#Negative value imputation
def Negative_value_impute(df,value,imptype):
    """
    Impute Negative value (can choose negative value to impute)
    df[DataFrame]:df
    imptype[string]: "mean" to impute data with mean, "median" to impute data with median
    """
    if imptype == "mean":        
        df = df.replace(value,df.mean())
    if imptype == "median":
        df = df.replace(value,df.median())
    return df

#Negative -5555 imputation with median
df_test = Negative_value_impute(df_test,value=-5555,imptype="median")
#Negative 999 imputation with median
df_test = Negative_value_impute(df_test,value=-999,imptype="median")
#Negative 9999 imputation with median
df_test = Negative_value_impute(df_test,value=-9999,imptype="median")
#Negative -555 imputation with median
df_test = Negative_value_impute(df_test,value=-555,imptype="median")
df_test.shape
# Out:
# (35957, 672)

# %%
(df_test < 0).any().any()
# Out:
# False

# %%
df_test.to_csv(path+"DataPreparation/Set3/Test_Set3_NegHandling.csv",index=False)

# %%
#check unary columns
def unary(df):
    """
    Checks for unary columns. If there are unary columns, the unary columns will be printed and removed from the df
    df[DataFrame]: input dataframe
    """
    unarycolumns = [col for col in df.columns if len(df[col].unique())==1]
    if unarycolumns:
        print("The unary column are:",unarycolumns)
        df = df.drop(unarycolumns,axis=1)
        print("Unary columns dropped!")
        return df 
    else:
        print("There are no unary columns!")
        
unary(df_test)
# Out:
# There are no unary columns!

# %%
#read merged train data
path = "C:/Users/nchong/OneDrive - Intel Corporation/Documents/ML based speckle POC/"
X_train = pd.read_csv(path+"DataPreparation/MergedData_SameVID/TrainData_NegHandling.csv")
y_train = X_train["SPECKLE"]
print(X_train.shape)
# Out:
# (36434, 1595)

# %%
X_train
# Out:
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSA_132110  \
# 0                                            0.7786
# 1                                            0.6512
# 2                                            0.7902
# 3                                            0.6857
# 4                                            0.9151
# ...                                             ...
# 36429                                        0.6000
# 36430                                        0.6400
# 36431                                        0.7302
# 36432                                        0.6942
# 36433                                        0.7386
#
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSAC6S_132110  \
# 0                                               0.6832
# 1                                               0.5800
# 2                                               0.7089
# 3                                               0.6013
# 4                                               0.7373
# ...                                                ...
# 36429                                           0.6000
# 36430                                           0.6000
# 36431                                           0.6089
# 36432                                           0.5800
# 36433                                           0.5800
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACCIS5_132110  \
# 0                                                0.56
# 1                                                0.54
# 2                                                0.56
# 3                                                0.52
# 4                                                0.58
# ...                                               ...
# 36429                                            0.54
# 36430                                            0.54
# 36431                                            0.56
# 36432                                            0.56
# 36433                                            0.56
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPK_132110  \
# 0                                            0.6977
# 1                                            0.7030
# 2                                            0.7211
# 3                                            0.6923
# 4                                            0.7109
# ...                                             ...
# 36429                                        0.6800
# 36430                                        0.7133
# 36431                                        0.7211
# 36432                                        0.7089
# 36433                                        0.7177
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPM_132110  \
# 0                                            0.6600
# 1                                            0.6801
# 2                                            0.6984
# 3                                            0.6508
# 4                                            0.7069
# ...                                             ...
# 36429                                        0.6400
# 36430                                        0.6690
# 36431                                        0.6984
# 36432                                        0.6852
# 36433                                        0.6928
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMCPR_132110  \
# 0                                               0.6600
# 1                                               0.6762
# 2                                               0.6946
# 3                                               0.6471
# 4                                               0.7029
# ...                                                ...
# 36429                                           0.6400
# 36430                                           0.6650
# 36431                                           0.6946
# 36432                                           0.6812
# 36433                                           0.6887
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMPKE_132110  \
# 0                                               0.6619
# 1                                               0.6698
# 2                                               0.6882
# 3                                               0.6410
# 4                                               0.6963
# ...                                                ...
# 36429                                           0.6200
# 36430                                           0.6583
# 36431                                           0.6882
# 36432                                           0.6747
# 36433                                           0.7019
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAHLP_132110  \
# 0                                            0.6600
# 1                                            0.6609
# 2                                            0.6789
# 3                                            0.6699
# 4                                            0.7088
# ...                                             ...
# 36429                                        0.6400
# 36430                                        0.6713
# 36431                                        0.6789
# 36432                                        0.6868
# 36433                                        0.6758
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAIRC_132110  \
# 0                                            0.6400
# 1                                            0.6537
# 2                                            0.6921
# 3                                            0.6451
# 4                                            0.6999
# ...                                             ...
# 36429                                        0.6317
# 36430                                        0.6619
# 36431                                        0.6921
# 36432                                        0.6784
# 36433                                        0.6854
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSARMN0_132110  ...  \
# 0                                             0.6200  ...
# 1                                             0.6529  ...
# 2                                             0.6714  ...
# 3                                             0.6249  ...
# 4                                             0.6587  ...
# ...                                              ...  ...
# 36429                                         0.6000  ...
# 36430                                         0.6405  ...
# 36431                                         0.6514  ...
# 36432                                         0.6572  ...
# 36433                                         0.6637  ...
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_SVIDDATA0  \
# 0                                           7.830000e-07
# 1                                           9.470000e-07
# 2                                           1.210000e-06
# 3                                           6.860000e-07
# 4                                           1.260000e-06
# ...                                                  ...
# 36429                                       6.400000e-07
# 36430                                       7.420000e-07
# 36431                                       8.490000e-07
# 36432                                       1.090000e-06
# 36433                                       9.490000e-07
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_SVIDDATA1  \
# 0                                           8.270000e-07
# 1                                           9.390000e-07
# 2                                           1.240000e-06
# 3                                           6.600000e-07
# 4                                           1.280000e-06
# ...                                                  ...
# 36429                                       6.440000e-07
# 36430                                       7.040000e-07
# 36431                                       8.660000e-07
# 36432                                       1.090000e-06
# 36433                                       9.460000e-07
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_TAP_DIS_STRAP_N  \
# 0                                           1.800000e-07
# 1                                           2.350000e-07
# 2                                           2.830000e-07
# 3                                           1.560000e-07
# 4                                           2.890000e-07
# ...                                                  ...
# 36429                                       1.510000e-07
# 36430                                       1.740000e-07
# 36431                                       2.070000e-07
# 36432                                       2.750000e-07
# 36433                                       2.630000e-07
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_TAP_ODT_EN  \
# 0                                           2.040000e-07
# 1                                           2.280000e-07
# 2                                           2.980000e-07
# 3                                           1.700000e-07
# 4                                           3.310000e-07
# ...                                                  ...
# 36429                                       1.660000e-07
# 36430                                       2.200000e-07
# 36431                                       2.080000e-07
# 36432                                       2.770000e-07
# 36433                                       2.640000e-07
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_TXT_AGENT  \
# 0                                           1.950000e-07
# 1                                           2.400000e-07
# 2                                           3.090000e-07
# 3                                           1.630000e-07
# 4                                           3.200000e-07
# ...                                                  ...
# 36429                                       1.500000e-07
# 36430                                       1.630000e-07
# 36431                                       1.980000e-07
# 36432                                       2.740000e-07
# 36433                                       2.720000e-07
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_TXT_PLTEN  \
# 0                                           2.240000e-07
# 1                                           2.290000e-07
# 2                                           2.900000e-07
# 3                                           1.470000e-07
# 4                                           3.110000e-07
# ...                                                  ...
# 36429                                       1.600000e-07
# 36430                                       1.640000e-07
# 36431                                       2.340000e-07
# 36432                                       2.940000e-07
# 36433                                       2.260000e-07
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_VPPSMBUSSCL  \
# 0                                           7.780000e-07
# 1                                           9.430000e-07
# 2                                           1.210000e-06
# 3                                           6.330000e-07
# 4                                           1.270000e-06
# ...                                                  ...
# 36429                                       6.540000e-07
# 36430                                       7.470000e-07
# 36431                                       8.610000e-07
# 36432                                       1.100000e-06
# 36433                                       9.680000e-07
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_VPPSMBUSSDA  \
# 0                                           7.550000e-07
# 1                                           9.530000e-07
# 2                                           1.130000e-06
# 3                                           6.490000e-07
# 4                                           1.250000e-06
# ...                                                  ...
# 36429                                       6.540000e-07
# 36430                                       7.640000e-07
# 36431                                       8.530000e-07
# 36432                                       1.110000e-06
# 36433                                       9.790000e-07
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_VSENSEPMAX  \
# 0                                           1.720000e-07
# 1                                           2.490000e-07
# 2                                           2.990000e-07
# 3                                           1.500000e-07
# 4                                           2.880000e-07
# ...                                                  ...
# 36429                                       1.790000e-07
# 36430                                       1.900000e-07
# 36431                                       2.110000e-07
# 36432                                       3.040000e-07
# 36433                                       2.590000e-07
#
#        SPECKLE
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 36429        0
# 36430        0
# 36431        0
# 36432        0
# 36433        1
#
# [36434 rows x 1595 columns]

# %%
X_test = df_test.copy()
X_test
# Out:
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSA_132110  \
# 0                                            0.7549
# 1                                            0.7761
# 2                                            0.7356
# 3                                            0.6656
# 4                                            0.6646
# ...                                             ...
# 35952                                        0.7054
# 35953                                        0.7301
# 35954                                        0.7611
# 35955                                        0.7652
# 35956                                        0.7886
#
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSAC6S_132110  \
# 0                                               0.7169
# 1                                               0.6990
# 2                                               0.7118
# 3                                               0.6749
# 4                                               0.6533
# ...                                                ...
# 35952                                           0.6545
# 35953                                           0.6200
# 35954                                           0.6674
# 35955                                           0.6805
# 35956                                           0.7600
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACCIS5_132110  \
# 0                                                0.56
# 1                                                0.50
# 2                                                0.52
# 3                                                0.48
# 4                                                0.48
# ...                                               ...
# 35952                                            0.50
# 35953                                            0.52
# 35954                                            0.48
# 35955                                            0.46
# 35956                                            0.50
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPK_132110  \
# 0                                            0.7504
# 1                                            0.7128
# 2                                            0.7310
# 3                                            0.7000
# 4                                            0.7095
# ...                                             ...
# 35952                                        0.7309
# 35953                                        0.7602
# 35954                                        0.7026
# 35955                                        0.6713
# 35956                                        0.7173
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPM_132110  \
# 0                                            0.6865
# 1                                            0.6886
# 2                                            0.7000
# 3                                            0.6800
# 4                                            0.6829
# ...                                             ...
# 35952                                        0.7042
# 35953                                        0.7322
# 35954                                        0.6770
# 35955                                        0.6700
# 35956                                        0.6897
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMCPR_132110  \
# 0                                               0.6825
# 1                                               0.6846
# 2                                               0.6800
# 3                                               0.6600
# 4                                               0.6787
# ...                                                ...
# 35952                                           0.7000
# 35953                                           0.7279
# 35954                                           0.6929
# 35955                                           0.6662
# 35956                                           0.6854
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMPKE_132110  \
# 0                                               0.6759
# 1                                               0.6779
# 2                                               0.6800
# 3                                               0.6600
# 4                                               0.6600
# ...                                                ...
# 35952                                           0.6927
# 35953                                           0.7203
# 35954                                           0.6659
# 35955                                           0.6200
# 35956                                           0.6779
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAHLP_132110  \
# 0                                            0.7283
# 1                                            0.7108
# 2                                            0.7000
# 3                                            0.6800
# 4                                            0.6877
# ...                                             ...
# 35952                                        0.7092
# 35953                                        0.7386
# 35954                                        0.6808
# 35955                                        0.6689
# 35956                                        0.6957
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAIRC_132110  \
# 0                                            0.7395
# 1                                            0.6615
# 2                                            0.6719
# 3                                            0.6400
# 4                                            0.6547
# ...                                             ...
# 35952                                        0.6959
# 35953                                        0.7233
# 35954                                        0.6400
# 35955                                        0.6243
# 35956                                        0.6810
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSARMN0_132110  ...  \
# 0                                             0.6383  ...
# 1                                             0.6401  ...
# 2                                             0.6600  ...
# 3                                             0.6400  ...
# 4                                             0.6524  ...
# ...                                              ...  ...
# 35952                                         0.6735  ...
# 35953                                         0.7004  ...
# 35954                                         0.6200  ...
# 35955                                         0.6242  ...
# 35956                                         0.6582  ...
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFUSEHV2_V1_132150  \
# 0                                               0.001220
# 1                                               0.001090
# 2                                               0.000864
# 3                                               0.000616
# 4                                               0.001470
# ...                                                  ...
# 35952                                           0.000793
# 35953                                           0.001750
# 35954                                           0.000741
# 35955                                           0.000771
# 35956                                           0.002190
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCINF_V1_132110  \
# 0                                               0.061762
# 1                                               0.063405
# 2                                               0.038258
# 3                                               0.048783
# 4                                               0.054818
# ...                                                  ...
# 35952                                           0.059004
# 35953                                           0.039030
# 35954                                           0.058706
# 35955                                           0.057559
# 35956                                           0.055522
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132110  \
# 0                                               0.101282
# 1                                               0.098775
# 2                                               0.100102
# 3                                               0.101898
# 4                                               0.103240
# ...                                                  ...
# 35952                                           0.107691
# 35953                                           0.104464
# 35954                                           0.104824
# 35955                                           0.105340
# 35956                                           0.102586
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132150  \
# 0                                               0.101282
# 1                                               0.098775
# 2                                               0.100102
# 3                                               0.101898
# 4                                               0.103240
# ...                                                  ...
# 35952                                           0.107691
# 35953                                           0.104464
# 35954                                           0.104824
# 35955                                           0.105340
# 35956                                           0.102586
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCRAM_M012345_V1_132110  \
# 0                                               0.129697
# 1                                               0.125215
# 2                                               0.043657
# 3                                               0.090991
# 4                                               0.143294
# ...                                                  ...
# 35952                                           0.141604
# 35953                                           0.059089
# 35954                                           0.104052
# 35955                                           0.138233
# 35956                                           0.046624
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSA_V1_132110  \
# 0                                               0.144388
# 1                                               0.160947
# 2                                               0.128603
# 3                                               0.143191
# 4                                               0.141019
# ...                                                  ...
# 35952                                           0.126801
# 35953                                           0.118446
# 35954                                           0.152348
# 35955                                           0.159376
# 35956                                           0.146967
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSFR_HV_V1_132150  \
# 0                                               0.016616
# 1                                               0.016679
# 2                                               0.017228
# 3                                               0.018593
# 4                                               0.016770
# ...                                                  ...
# 35952                                           0.013791
# 35953                                           0.013602
# 35954                                           0.016198
# 35955                                           0.016566
# 35956                                           0.016198
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCVNN_V1_132110  \
# 0                                               0.370098
# 1                                               0.238482
# 2                                               0.112978
# 3                                               0.208768
# 4                                               0.147160
# ...                                                  ...
# 35952                                           0.217900
# 35953                                           0.232171
# 35954                                           0.446311
# 35955                                           0.304388
# 35956                                           0.263493
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCCLM_V1_132150  \
# 0                                               0.298004
# 1                                               0.267327
# 2                                               0.143718
# 3                                               0.258959
# 4                                               0.584695
# ...                                                  ...
# 35952                                           0.395498
# 35953                                           0.266982
# 35954                                           0.364429
# 35955                                           0.258331
# 35956                                           0.176275
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCINPMAXQ_V1_132150
# 0                                           8.570000e-06
# 1                                           9.030000e-06
# 2                                           2.200000e-05
# 3                                           1.750000e-05
# 4                                           3.240000e-05
# ...                                                  ...
# 35952                                       7.430000e-06
# 35953                                       5.380000e-06
# 35954                                       2.450000e-06
# 35955                                       3.890000e-05
# 35956                                       5.140000e-07
#
# [35957 rows x 672 columns]

# %%
#make order of features in train same as test before normalization to make sure test norm according to train features
X_train = X_train[X_test.columns]
X_train
# Out:
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSA_132110  \
# 0                                            0.7786
# 1                                            0.6512
# 2                                            0.7902
# 3                                            0.6857
# 4                                            0.9151
# ...                                             ...
# 36429                                        0.6000
# 36430                                        0.6400
# 36431                                        0.7302
# 36432                                        0.6942
# 36433                                        0.7386
#
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSAC6S_132110  \
# 0                                               0.6832
# 1                                               0.5800
# 2                                               0.7089
# 3                                               0.6013
# 4                                               0.7373
# ...                                                ...
# 36429                                           0.6000
# 36430                                           0.6000
# 36431                                           0.6089
# 36432                                           0.5800
# 36433                                           0.5800
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACCIS5_132110  \
# 0                                                0.56
# 1                                                0.54
# 2                                                0.56
# 3                                                0.52
# 4                                                0.58
# ...                                               ...
# 36429                                            0.54
# 36430                                            0.54
# 36431                                            0.56
# 36432                                            0.56
# 36433                                            0.56
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPK_132110  \
# 0                                            0.6977
# 1                                            0.7030
# 2                                            0.7211
# 3                                            0.6923
# 4                                            0.7109
# ...                                             ...
# 36429                                        0.6800
# 36430                                        0.7133
# 36431                                        0.7211
# 36432                                        0.7089
# 36433                                        0.7177
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPM_132110  \
# 0                                            0.6600
# 1                                            0.6801
# 2                                            0.6984
# 3                                            0.6508
# 4                                            0.7069
# ...                                             ...
# 36429                                        0.6400
# 36430                                        0.6690
# 36431                                        0.6984
# 36432                                        0.6852
# 36433                                        0.6928
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMCPR_132110  \
# 0                                               0.6600
# 1                                               0.6762
# 2                                               0.6946
# 3                                               0.6471
# 4                                               0.7029
# ...                                                ...
# 36429                                           0.6400
# 36430                                           0.6650
# 36431                                           0.6946
# 36432                                           0.6812
# 36433                                           0.6887
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMPKE_132110  \
# 0                                               0.6619
# 1                                               0.6698
# 2                                               0.6882
# 3                                               0.6410
# 4                                               0.6963
# ...                                                ...
# 36429                                           0.6200
# 36430                                           0.6583
# 36431                                           0.6882
# 36432                                           0.6747
# 36433                                           0.7019
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAHLP_132110  \
# 0                                            0.6600
# 1                                            0.6609
# 2                                            0.6789
# 3                                            0.6699
# 4                                            0.7088
# ...                                             ...
# 36429                                        0.6400
# 36430                                        0.6713
# 36431                                        0.6789
# 36432                                        0.6868
# 36433                                        0.6758
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAIRC_132110  \
# 0                                            0.6400
# 1                                            0.6537
# 2                                            0.6921
# 3                                            0.6451
# 4                                            0.6999
# ...                                             ...
# 36429                                        0.6317
# 36430                                        0.6619
# 36431                                        0.6921
# 36432                                        0.6784
# 36433                                        0.6854
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSARMN0_132110  ...  \
# 0                                             0.6200  ...
# 1                                             0.6529  ...
# 2                                             0.6714  ...
# 3                                             0.6249  ...
# 4                                             0.6587  ...
# ...                                              ...  ...
# 36429                                         0.6000  ...
# 36430                                         0.6405  ...
# 36431                                         0.6514  ...
# 36432                                         0.6572  ...
# 36433                                         0.6637  ...
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFUSEHV2_V1_132150  \
# 0                                               0.004580
# 1                                               0.004734
# 2                                               0.007800
# 3                                               0.005363
# 4                                               0.003197
# ...                                                  ...
# 36429                                           0.003605
# 36430                                           0.004493
# 36431                                           0.002049
# 36432                                           0.002249
# 36433                                           0.000144
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCINF_V1_132110  \
# 0                                               0.041523
# 1                                               0.057365
# 2                                               0.062772
# 3                                               0.066186
# 4                                               0.054719
# ...                                                  ...
# 36429                                           0.052927
# 36430                                           0.039778
# 36431                                           0.050743
# 36432                                           0.072028
# 36433                                           0.051072
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132110  \
# 0                                               0.107685
# 1                                               0.101809
# 2                                               0.106149
# 3                                               0.104523
# 4                                               0.103080
# ...                                                  ...
# 36429                                           0.102695
# 36430                                           0.101351
# 36431                                           0.104520
# 36432                                           0.101805
# 36433                                           0.101399
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132150  \
# 0                                               0.111300
# 1                                               0.105788
# 2                                               0.113978
# 3                                               0.108897
# 4                                               0.109861
# ...                                                  ...
# 36429                                           0.108356
# 36430                                           0.107246
# 36431                                           0.111128
# 36432                                           0.105452
# 36433                                           0.106329
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCRAM_M012345_V1_132110  \
# 0                                               0.015977
# 1                                               0.122849
# 2                                               0.090806
# 3                                               0.080744
# 4                                               0.066673
# ...                                                  ...
# 36429                                           0.090052
# 36430                                           0.085222
# 36431                                           0.129183
# 36432                                           0.146570
# 36433                                           0.094500
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSA_V1_132110  \
# 0                                               0.114810
# 1                                               0.138051
# 2                                               0.158590
# 3                                               0.154961
# 4                                               0.149652
# ...                                                  ...
# 36429                                           0.138190
# 36430                                           0.133830
# 36431                                           0.152247
# 36432                                           0.140420
# 36433                                           0.142429
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSFR_HV_V1_132150  \
# 0                                               0.018642
# 1                                               0.015006
# 2                                               0.019516
# 3                                               0.018999
# 4                                               0.017634
# ...                                                  ...
# 36429                                           0.019524
# 36430                                           0.019792
# 36431                                           0.017918
# 36432                                           0.016317
# 36433                                           0.017550
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCVNN_V1_132110  \
# 0                                               0.211570
# 1                                               0.356722
# 2                                               0.476278
# 3                                               0.182989
# 4                                               0.435512
# ...                                                  ...
# 36429                                           0.335095
# 36430                                           0.196845
# 36431                                           0.356445
# 36432                                           0.186246
# 36433                                           0.261810
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCCLM_V1_132150  \
# 0                                                1.69584
# 1                                                2.13755
# 2                                                4.39068
# 3                                                2.35009
# 4                                                2.85145
# ...                                                  ...
# 36429                                            2.03884
# 36430                                            1.49184
# 36431                                            2.61788
# 36432                                            2.02123
# 36433                                            1.89781
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCINPMAXQ_V1_132150
# 0                                               0.002062
# 1                                               0.000580
# 2                                               0.000539
# 3                                               0.001832
# 4                                               0.001187
# ...                                                  ...
# 36429                                           0.001475
# 36430                                           0.000592
# 36431                                           0.001266
# 36432                                           0.001372
# 36433                                           0.000877
#
# [36434 rows x 672 columns]

# %%
from collections import Counter
y_test = df_test["SPECKLE"]
print(Counter(y_test))
print(X_test.shape)
print(X_train.shape)
# Out:
# Counter({0: 35866, 1: 91})
# (35957, 672)
# (36434, 672)

# %%
X_train = X_train.drop(["SPECKLE"],axis=1)
X_test = X_test.drop(["SPECKLE"],axis=1)

# %%
#Normalize the data
import joblib
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_train_scaled = pd.DataFrame(X_train_scaled,columns= X_train.columns)
X_test_scaled = scaler.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled,columns= X_test.columns)  
print(X_train_scaled.shape)
print(X_test_scaled.shape)
# Out:
# (36434, 671)
# (35957, 671)

# %%
X_train_scaled
# Out:
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSA_132110  \
# 0                                          0.476031
# 1                                          0.170662
# 2                                          0.503835
# 3                                          0.253356
# 4                                          0.803212
# ...                                             ...
# 36429                                      0.047939
# 36430                                      0.143816
# 36431                                      0.360019
# 36432                                      0.273730
# 36433                                      0.380153
#
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSAC6S_132110  \
# 0                                             0.285053
# 1                                             0.046275
# 2                                             0.344516
# 3                                             0.095558
# 4                                             0.410227
# ...                                                ...
# 36429                                         0.092550
# 36430                                         0.092550
# 36431                                         0.113142
# 36432                                         0.046275
# 36433                                         0.046275
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACCIS5_132110  \
# 0                                            0.166667
# 1                                            0.111111
# 2                                            0.166667
# 3                                            0.055556
# 4                                            0.222222
# ...                                               ...
# 36429                                        0.111111
# 36430                                        0.111111
# 36431                                        0.166667
# 36432                                        0.166667
# 36433                                        0.166667
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPK_132110  \
# 0                                          0.281534
# 1                                          0.308274
# 2                                          0.399596
# 3                                          0.254289
# 4                                          0.348133
# ...                                             ...
# 36429                                      0.192230
# 36430                                      0.360242
# 36431                                      0.399596
# 36432                                      0.338042
# 36433                                      0.382442
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPM_132110  \
# 0                                          0.180995
# 1                                          0.271946
# 2                                          0.354751
# 3                                          0.139367
# 4                                          0.393213
# ...                                             ...
# 36429                                      0.090498
# 36430                                      0.221719
# 36431                                      0.354751
# 36432                                      0.295023
# 36433                                      0.329412
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMCPR_132110  \
# 0                                             0.105625
# 1                                             0.148402
# 2                                             0.196990
# 3                                             0.071561
# 4                                             0.218907
# ...                                                ...
# 36429                                         0.052812
# 36430                                         0.118828
# 36431                                         0.196990
# 36432                                         0.161605
# 36433                                         0.181410
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMPKE_132110  \
# 0                                             0.119237
# 1                                             0.141719
# 2                                             0.194081
# 3                                             0.059761
# 4                                             0.217131
# ...                                                ...
# 36429                                         0.000000
# 36430                                         0.108993
# 36431                                         0.194081
# 36432                                         0.155663
# 36433                                         0.233068
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAHLP_132110  \
# 0                                          0.213904
# 1                                          0.218717
# 2                                          0.314973
# 3                                          0.266845
# 4                                          0.474866
# ...                                             ...
# 36429                                      0.106952
# 36430                                      0.274332
# 36431                                      0.314973
# 36432                                      0.357219
# 36433                                      0.298396
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAIRC_132110  \
# 0                                          0.248948
# 1                                          0.331329
# 2                                          0.562237
# 3                                          0.279615
# 4                                          0.609140
# ...                                             ...
# 36429                                      0.199038
# 36430                                      0.380637
# 36431                                      0.562237
# 36432                                      0.479856
# 36433                                      0.521948
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSARMN0_132110  ...  \
# 0                                           0.250627  ...
# 1                                           0.456767  ...
# 2                                           0.572682  ...
# 3                                           0.281328  ...
# 4                                           0.493108  ...
# ...                                              ...  ...
# 36429                                       0.125313  ...
# 36430                                       0.379073  ...
# 36431                                       0.447368  ...
# 36432                                       0.483709  ...
# 36433                                       0.524436  ...
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFUSEHV2_V1_132150  \
# 0                                               0.233964
# 1                                               0.241856
# 2                                               0.398472
# 3                                               0.273990
# 4                                               0.163305
# ...                                                  ...
# 36429                                           0.184158
# 36430                                           0.229552
# 36431                                           0.104692
# 36432                                           0.114869
# 36433                                           0.007370
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCINF_V1_132110  \
# 0                                               0.108646
# 1                                               0.210434
# 2                                               0.245177
# 3                                               0.267109
# 4                                               0.193432
# ...                                                  ...
# 36429                                           0.181920
# 36430                                           0.097437
# 36431                                           0.167888
# 36432                                           0.304651
# 36433                                           0.170000
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132110  \
# 0                                               0.091876
# 1                                               0.063635
# 2                                               0.084494
# 3                                               0.076679
# 4                                               0.069744
# ...                                                  ...
# 36429                                           0.067893
# 36430                                           0.061434
# 36431                                           0.076665
# 36432                                           0.063616
# 36433                                           0.061664
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132150  \
# 0                                               0.082351
# 1                                               0.051867
# 2                                               0.097162
# 3                                               0.069061
# 4                                               0.074393
# ...                                                  ...
# 36429                                           0.066069
# 36430                                           0.059930
# 36431                                           0.081400
# 36432                                           0.050009
# 36433                                           0.054859
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCRAM_M012345_V1_132110  \
# 0                                               0.030714
# 1                                               0.265368
# 2                                               0.195012
# 3                                               0.172920
# 4                                               0.142024
# ...                                                  ...
# 36429                                           0.193356
# 36430                                           0.182753
# 36431                                           0.279275
# 36432                                           0.317451
# 36433                                           0.203122
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSA_V1_132110  \
# 0                                               0.147435
# 1                                               0.284780
# 2                                               0.406157
# 3                                               0.384711
# 4                                               0.353337
# ...                                                  ...
# 36429                                           0.285601
# 36430                                           0.259835
# 36431                                           0.368672
# 36432                                           0.298780
# 36433                                           0.310652
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSFR_HV_V1_132150  \
# 0                                               0.211568
# 1                                               0.077446
# 2                                               0.243807
# 3                                               0.224748
# 4                                               0.174394
# ...                                                  ...
# 36429                                           0.244102
# 36430                                           0.253980
# 36431                                           0.184863
# 36432                                           0.125808
# 36433                                           0.171307
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCVNN_V1_132110  \
# 0                                               0.101961
# 1                                               0.212699
# 2                                               0.303910
# 3                                               0.080156
# 4                                               0.272809
# ...                                                  ...
# 36429                                           0.196199
# 36430                                           0.090727
# 36431                                           0.212488
# 36432                                           0.082641
# 36433                                           0.140289
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCCLM_V1_132150  \
# 0                                               0.218465
# 1                                               0.309075
# 2                                               0.771271
# 3                                               0.352675
# 4                                               0.455521
# ...                                                  ...
# 36429                                           0.288826
# 36430                                           0.176618
# 36431                                           0.407608
# 36432                                           0.285214
# 36433                                           0.259896
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCINPMAXQ_V1_132150
# 0                                               0.375536
# 1                                               0.105601
# 2                                               0.098134
# 3                                               0.333704
# 4                                               0.216220
# ...                                                  ...
# 36429                                           0.268597
# 36430                                           0.107750
# 36431                                           0.230607
# 36432                                           0.249911
# 36433                                           0.159708
#
# [36434 rows x 671 columns]

# %%
X_test_scaled
# Out:
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSA_132110  \
# 0                                          0.419223
# 1                                          0.470038
# 2                                          0.372963
# 3                                          0.205177
# 4                                          0.202780
# ...                                             ...
# 35952                                      0.300575
# 35953                                      0.359779
# 35954                                      0.434084
# 35955                                      0.443912
# 35956                                      0.500000
#
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSAC6S_132110  \
# 0                                             0.363026
# 1                                             0.321610
# 2                                             0.351226
# 3                                             0.265849
# 4                                             0.215872
# ...                                                ...
# 35952                                         0.218649
# 35953                                         0.138825
# 35954                                         0.248496
# 35955                                         0.278806
# 35956                                         0.462749
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACCIS5_132110  \
# 0                                            0.166667
# 1                                            0.000000
# 2                                            0.055556
# 3                                           -0.055556
# 4                                           -0.055556
# ...                                               ...
# 35952                                        0.000000
# 35953                                        0.055556
# 35954                                       -0.055556
# 35955                                       -0.111111
# 35956                                        0.000000
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPK_132110  \
# 0                                          0.547427
# 1                                          0.357719
# 2                                          0.449546
# 3                                          0.293138
# 4                                          0.341070
# ...                                             ...
# 35952                                      0.449041
# 35953                                      0.596872
# 35954                                      0.306256
# 35955                                      0.148335
# 35956                                      0.380424
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPM_132110  \
# 0                                          0.300905
# 1                                          0.310407
# 2                                          0.361991
# 3                                          0.271493
# 4                                          0.284615
# ...                                             ...
# 35952                                      0.380995
# 35953                                      0.507692
# 35954                                      0.257919
# 35955                                      0.226244
# 35956                                      0.315385
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMCPR_132110  \
# 0                                             0.165038
# 1                                             0.170584
# 2                                             0.158437
# 3                                             0.105625
# 4                                             0.155004
# ...                                                ...
# 35952                                         0.211249
# 35953                                         0.284922
# 35954                                         0.192501
# 35955                                         0.121996
# 35956                                         0.172696
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMPKE_132110  \
# 0                                             0.159078
# 1                                             0.164769
# 2                                             0.170746
# 3                                             0.113830
# 4                                             0.113830
# ...                                                ...
# 35952                                         0.206887
# 35953                                         0.285430
# 35954                                         0.130620
# 35955                                         0.000000
# 35956                                         0.164769
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAHLP_132110  \
# 0                                          0.579144
# 1                                          0.485561
# 2                                          0.427807
# 3                                          0.320856
# 4                                          0.362032
# ...                                             ...
# 35952                                      0.477005
# 35953                                      0.634225
# 35954                                      0.325134
# 35955                                      0.261497
# 35956                                      0.404813
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAIRC_132110  \
# 0                                          0.847264
# 1                                          0.378232
# 2                                          0.440770
# 3                                          0.248948
# 4                                          0.337342
# ...                                             ...
# 35952                                      0.585087
# 35953                                      0.749850
# 35954                                      0.248948
# 35955                                      0.154540
# 35956                                      0.495490
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSARMN0_132110  ...  \
# 0                                           0.365288  ...
# 1                                           0.376566  ...
# 2                                           0.501253  ...
# 3                                           0.375940  ...
# 4                                           0.453634  ...
# ...                                              ...  ...
# 35952                                       0.585840  ...
# 35953                                       0.754386  ...
# 35954                                       0.250627  ...
# 35955                                       0.276942  ...
# 35956                                       0.489975  ...
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFUSEHV2_V1_132150  \
# 0                                               0.062325
# 1                                               0.055683
# 2                                               0.044138
# 3                                               0.031468
# 4                                               0.075097
# ...                                                  ...
# 35952                                           0.040510
# 35953                                           0.089401
# 35954                                           0.037854
# 35955                                           0.039386
# 35956                                           0.111880
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCINF_V1_132110  \
# 0                                               0.238686
# 1                                               0.249246
# 2                                               0.087665
# 3                                               0.155293
# 4                                               0.194073
# ...                                                  ...
# 35952                                           0.220965
# 35953                                           0.092629
# 35954                                           0.219049
# 35955                                           0.211679
# 35956                                           0.198595
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132110  \
# 0                                               0.061102
# 1                                               0.049055
# 2                                               0.055431
# 3                                               0.064063
# 4                                               0.070513
# ...                                                  ...
# 35952                                           0.091905
# 35953                                           0.076395
# 35954                                           0.078126
# 35955                                           0.080606
# 35956                                           0.067369
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132150  \
# 0                                               0.026946
# 1                                               0.013083
# 2                                               0.020420
# 3                                               0.030353
# 4                                               0.037775
# ...                                                  ...
# 35952                                           0.062391
# 35953                                           0.044544
# 35954                                           0.046535
# 35955                                           0.049389
# 35956                                           0.034158
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCRAM_M012345_V1_132110  \
# 0                                               0.280404
# 1                                               0.270563
# 2                                               0.091491
# 3                                               0.195420
# 4                                               0.310258
# ...                                                  ...
# 35952                                           0.306547
# 35953                                           0.125373
# 35954                                           0.224096
# 35955                                           0.299146
# 35956                                           0.098006
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSA_V1_132110  \
# 0                                               0.322229
# 1                                               0.420086
# 2                                               0.228946
# 3                                               0.315155
# 4                                               0.302319
# ...                                                  ...
# 35952                                           0.218297
# 35953                                           0.168922
# 35954                                           0.369269
# 35955                                           0.410802
# 35956                                           0.337470
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSFR_HV_V1_132150  \
# 0                                               0.136863
# 1                                               0.139157
# 2                                               0.159407
# 3                                               0.209779
# 4                                               0.142525
# ...                                                  ...
# 35952                                           0.032655
# 35953                                           0.025680
# 35954                                           0.121418
# 35955                                           0.135011
# 35956                                           0.121440
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCVNN_V1_132110  \
# 0                                               0.222904
# 1                                               0.122492
# 2                                               0.026744
# 3                                               0.099823
# 4                                               0.052821
# ...                                                  ...
# 35952                                           0.106790
# 35953                                           0.117677
# 35954                                           0.281047
# 35955                                           0.172773
# 35956                                           0.141573
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCCLM_V1_132150  \
# 0                                              -0.068280
# 1                                              -0.074573
# 2                                              -0.099929
# 3                                              -0.076289
# 4                                              -0.009469
# ...                                                  ...
# 35952                                          -0.048280
# 35953                                          -0.074643
# 35954                                          -0.054654
# 35955                                          -0.076418
# 35956                                          -0.093251
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCINPMAXQ_V1_132150
# 0                                               0.001534
# 1                                               0.001617
# 2                                               0.003979
# 3                                               0.003160
# 4                                               0.005873
# ...                                                  ...
# 35952                                           0.001326
# 35953                                           0.000953
# 35954                                           0.000419
# 35955                                           0.007057
# 35956                                           0.000066
#
# [35957 rows x 671 columns]

# %%
pd.concat([X_train_scaled,y_train],axis=1).to_csv(path+"DataPreparation/Set3/Train_MergedDataSameVID_scaled.csv",index=False)
pd.concat([X_test_scaled,y_test],axis=1).to_csv(path+"DataPreparation/Set3/Test_Set3_Scaled.csv",index=False)

# %% [markdown]
# ### Model testing

# %%
import pandas as pd
from collections import Counter
path = "C:/Users/nchong/OneDrive - Intel Corporation/Documents/ML based speckle POC/"
test = pd.read_csv(path+"DataPreparation/Set3/Test_Set3_Scaled.csv")
# test = pd.read_csv(path+"DataPreparation/MergedData_WithC0stepping/TestData_Normalized.csv")
y_test = test["SPECKLE"]
X_test = test.drop(["SPECKLE"],axis=1)
print(Counter(y_test))
print(X_test.shape)
X_test
# Out:
# Counter({0: 35866, 1: 91})
# (35957, 671)
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSA_132110  \
# 0                                          0.419223
# 1                                          0.470038
# 2                                          0.372963
# 3                                          0.205177
# 4                                          0.202780
# ...                                             ...
# 35952                                      0.300575
# 35953                                      0.359779
# 35954                                      0.434084
# 35955                                      0.443912
# 35956                                      0.500000
#
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSAC6S_132110  \
# 0                                             0.363026
# 1                                             0.321610
# 2                                             0.351226
# 3                                             0.265849
# 4                                             0.215872
# ...                                                ...
# 35952                                         0.218649
# 35953                                         0.138825
# 35954                                         0.248496
# 35955                                         0.278806
# 35956                                         0.462749
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACCIS5_132110  \
# 0                                            0.166667
# 1                                            0.000000
# 2                                            0.055556
# 3                                           -0.055556
# 4                                           -0.055556
# ...                                               ...
# 35952                                        0.000000
# 35953                                        0.055556
# 35954                                       -0.055556
# 35955                                       -0.111111
# 35956                                        0.000000
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPK_132110  \
# 0                                          0.547427
# 1                                          0.357719
# 2                                          0.449546
# 3                                          0.293138
# 4                                          0.341070
# ...                                             ...
# 35952                                      0.449041
# 35953                                      0.596872
# 35954                                      0.306256
# 35955                                      0.148335
# 35956                                      0.380424
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPM_132110  \
# 0                                          0.300905
# 1                                          0.310407
# 2                                          0.361991
# 3                                          0.271493
# 4                                          0.284615
# ...                                             ...
# 35952                                      0.380995
# 35953                                      0.507692
# 35954                                      0.257919
# 35955                                      0.226244
# 35956                                      0.315385
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMCPR_132110  \
# 0                                             0.165038
# 1                                             0.170584
# 2                                             0.158437
# 3                                             0.105625
# 4                                             0.155004
# ...                                                ...
# 35952                                         0.211249
# 35953                                         0.284922
# 35954                                         0.192501
# 35955                                         0.121996
# 35956                                         0.172696
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSACPMPKE_132110  \
# 0                                             0.159078
# 1                                             0.164769
# 2                                             0.170746
# 3                                             0.113830
# 4                                             0.113830
# ...                                                ...
# 35952                                         0.206887
# 35953                                         0.285430
# 35954                                         0.130620
# 35955                                         0.000000
# 35956                                         0.164769
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAHLP_132110  \
# 0                                          0.579144
# 1                                          0.485561
# 2                                          0.427807
# 3                                          0.320856
# 4                                          0.362032
# ...                                             ...
# 35952                                      0.477005
# 35953                                      0.634225
# 35954                                      0.325134
# 35955                                      0.261497
# 35956                                      0.404813
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSAIRC_132110  \
# 0                                          0.847264
# 1                                          0.378232
# 2                                          0.440770
# 3                                          0.248948
# 4                                          0.337342
# ...                                             ...
# 35952                                      0.585087
# 35953                                      0.749850
# 35954                                      0.248948
# 35955                                      0.154540
# 35956                                      0.495490
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSARMN0_132110  ...  \
# 0                                           0.365288  ...
# 1                                           0.376566  ...
# 2                                           0.501253  ...
# 3                                           0.375940  ...
# 4                                           0.453634  ...
# ...                                              ...  ...
# 35952                                       0.585840  ...
# 35953                                       0.754386  ...
# 35954                                       0.250627  ...
# 35955                                       0.276942  ...
# 35956                                       0.489975  ...
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFUSEHV2_V1_132150  \
# 0                                               0.062325
# 1                                               0.055683
# 2                                               0.044138
# 3                                               0.031468
# 4                                               0.075097
# ...                                                  ...
# 35952                                           0.040510
# 35953                                           0.089401
# 35954                                           0.037854
# 35955                                           0.039386
# 35956                                           0.111880
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCINF_V1_132110  \
# 0                                               0.238686
# 1                                               0.249246
# 2                                               0.087665
# 3                                               0.155293
# 4                                               0.194073
# ...                                                  ...
# 35952                                           0.220965
# 35953                                           0.092629
# 35954                                           0.219049
# 35955                                           0.211679
# 35956                                           0.198595
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132110  \
# 0                                               0.061102
# 1                                               0.049055
# 2                                               0.055431
# 3                                               0.064063
# 4                                               0.070513
# ...                                                  ...
# 35952                                           0.091905
# 35953                                           0.076395
# 35954                                           0.078126
# 35955                                           0.080606
# 35956                                           0.067369
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCIOQ_V1_132150  \
# 0                                               0.026946
# 1                                               0.013083
# 2                                               0.020420
# 3                                               0.030353
# 4                                               0.037775
# ...                                                  ...
# 35952                                           0.062391
# 35953                                           0.044544
# 35954                                           0.046535
# 35955                                           0.049389
# 35956                                           0.034158
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCRAM_M012345_V1_132110  \
# 0                                               0.280404
# 1                                               0.270563
# 2                                               0.091491
# 3                                               0.195420
# 4                                               0.310258
# ...                                                  ...
# 35952                                           0.306547
# 35953                                           0.125373
# 35954                                           0.224096
# 35955                                           0.299146
# 35956                                           0.098006
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSA_V1_132110  \
# 0                                               0.322229
# 1                                               0.420086
# 2                                               0.228946
# 3                                               0.315155
# 4                                               0.302319
# ...                                                  ...
# 35952                                           0.218297
# 35953                                           0.168922
# 35954                                           0.369269
# 35955                                           0.410802
# 35956                                           0.337470
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCSFR_HV_V1_132150  \
# 0                                               0.136863
# 1                                               0.139157
# 2                                               0.159407
# 3                                               0.209779
# 4                                               0.142525
# ...                                                  ...
# 35952                                           0.032655
# 35953                                           0.025680
# 35954                                           0.121418
# 35955                                           0.135011
# 35956                                           0.121440
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCVNN_V1_132110  \
# 0                                               0.222904
# 1                                               0.122492
# 2                                               0.026744
# 3                                               0.099823
# 4                                               0.052821
# ...                                                  ...
# 35952                                           0.106790
# 35953                                           0.117677
# 35954                                           0.281047
# 35955                                           0.172773
# 35956                                           0.141573
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCCLM_V1_132150  \
# 0                                              -0.068280
# 1                                              -0.074573
# 2                                              -0.099929
# 3                                              -0.076289
# 4                                              -0.009469
# ...                                                  ...
# 35952                                          -0.048280
# 35953                                          -0.074643
# 35954                                          -0.054654
# 35955                                          -0.076418
# 35956                                          -0.093251
#
#        TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCINPMAXQ_V1_132150
# 0                                               0.001534
# 1                                               0.001617
# 2                                               0.003979
# 3                                               0.003160
# 4                                               0.005873
# ...                                                  ...
# 35952                                           0.001326
# 35953                                           0.000953
# 35954                                           0.000419
# 35955                                           0.007057
# 35956                                           0.000066
#
# [35957 rows x 671 columns]

# %%
X_test_sf = pd.read_csv(path+"DataPreparation/Set3/Test_Set3_MappedtoB3_SF.csv")
# X_test_sf = pd.read_csv(path+"DataPreparation/MergedData_WithC0stepping/SupFeatures_Test.csv")
X_test_sf
# Out:
#                  VID   SORTLOT  WAFER  XLOC  YLOC TEST RESULTS  \
# 0      M2LH384800140  N1333240    833    -5    -3      B000000
# 1      M2LH384800126  N1333240    833    -2     7      B000000
# 2      M2LH384800018  N1331070    866     2    -9      B000000
# 3      M2LH384800015  N1331070    866     2    -2      B000000
# 4      M2LH384800011  N1331070    866    -6    -2      B000000
# ...              ...       ...    ...   ...   ...          ...
# 35952  M2JF162500004  N1352350    707     1     5      B010000
# 35953  M2R34A3500778  N1345270    505    -3    -5      B001000
# 35954  M2C6074701403  N1345550    353     2     0      B001000
# 35955  M2C6074700195  N1352350    708     0     1      B000001
# 35956  M26042R600832  N1345550    322     5    -6      B001000
#
#        TEST RESULTS BITS  TR_BITS INCOMING  INCOMING BITS  INC_BITS OUTGOING  \
# 0                      0        0  B000000              0         0  B000000
# 1                      0        0  B000000              0         0  B000000
# 2                      0        0  B000000              0         0  B000000
# 3                      0        0  B000000              0         0  B000000
# 4                      0        0  B000000              0         0  B000000
# ...                  ...      ...      ...            ...       ...      ...
# 35952              10000        1  B000000              0         0  B010000
# 35953               1000        1  B000000              0         0  B001000
# 35954               1000        1  B000000              0         0  B001000
# 35955                  1        1  B000000              0         0  B000001
# 35956               1000        1  B000000              0         0  B001000
#
#        OUTGOING BITS  OUT_BITS  DELTA  IB@6261[CLASSHOT]  FB@6261[CLASSHOT]
# 0                  0         0      0                  1                101
# 1                  0         0      0                  1                101
# 2                  0         0      0                  1                101
# 3                  0         0      0                  1                101
# 4                  0         0      0                  1                101
# ...              ...       ...    ...                ...                ...
# 35952          10000         1      1                  1                101
# 35953           1000         1      1                  1                101
# 35954           1000         1      1                  1                101
# 35955              1         1      1                  1                101
# 35956           1000         1      1                  1                101
#
# [35957 rows x 17 columns]

# %%
#filter test by important features
features = pd.read_csv(path + "/FeatureSelection/SNR_R5_ww51.4/EnsembleTop300Fs.csv")
# features = pd.read_csv(path + "/FeatureSelection/MergedData_TrainValExchange/Boruta.csv")
X_test = X_test[features["Feature"]]
# fs= ["TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCCORE_M01_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFAD_GPIO_DTS_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCAOPI_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCCLM_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFAD_RMN012_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFA_RMN012_EHV_V1_132150","IDV_0113_NOMNDN12_FULLDIE_CORE_TALL_0650_MED_132110","IDV_0118_SVTNDN12_FULLDIE_CORE_TALL_0650_MED_132110","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFUSE0_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCINPMAXQ_V1_132150","IDV_0148_SVTNLK12_FULLDIE_CORE_TALL_0650_MED_132110","TPI_VCC_X::CONT_PARALLEL_HC_E_START_X_X_X_X_
DDR_DQ_HV_132110","TPI_VCC::CONT_VCCDDRDQ_HC_K_START_X_X_X_X_POSTSURGE_SNR_MIMS_VCCDDR_DQ_HV_132110","TPI_SIU_STATIC::SIU_STATIC_AM_K_STRESS_X_X_X_SNR_HIGHV_SIUP_SICC_VCCDDRA_HIGHV_132110","TPI_VCC::CONT_PARALLEL_VLC_E_FINAL_X_X_X_X_SNR_MIMS_SNR_ALL_VCCPAR_VLCDPS_VCCFUSE2_132110","TPI_SIU_STATIC::SIU_STATIC_AM_K_STRESS_X_X_X_SNR_HIGHV_VBUMP_SIUP_SIUP_VCCCLM_HIGHV_132110","TPI_VCC::CONT_PARALLEL_VLC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_SNR_ALL_VCCPAR_VLCDPS_VCCFUSE1_132110","TPI_VCC::CONT_VCCCLM_HC_E_START_X_X_X_X_POSTSURGE_CCMEAS_MIMS_VCCCLM_132110","TPI_VCC_X::CONT_PARALLEL_LC_E_START_X_X_X_X_MIMS_SNR_ALL_VCCPAR_LCDPS_VCCIOQ_132150","TPI_VCC::CONT_VCCVNN_HC_K_START_X_X_X_X_POSTSURGE_SNR_OLD_VCCVNN_132110"]
# fs = ["HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSA_132110","IDV_0048_SVTNLK12_FULLDIE_SOC_0950_MED_132110","HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSAC6S_132110"]
# fs = ["TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCCORE_M01_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFAD_GPIO_DTS_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCAOPI_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCCLM_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFAD_RMN012_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFA_RMN012_EHV_V1_132150","IDV_0113_NOMNDN12_FULLDIE_CORE_TALL_0650_MED_132110","IDV_0118_SVTNDN12_FULLDIE_CORE_TALL_0650_MED_132110","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFUSE0_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SIUP_VCCINPMAXQ_V1_132150","IDV_0148_SVTNLK12_FULLDIE_CORE_TALL_0650_MED_132110","TPI_VCC_X::CONT_PARALLEL_HC_E_START_X_X_X_X_MIMS_SN
T_PARALLEL_VLC_E_FINAL_X_X_X_X_SNR_MIMS_SNR_ALL_VCCPAR_VLCDPS_VCCFUSE2_132110","TPI_SIU_STATIC::SIU_STATIC_AM_K_STRESS_X_X_X_SNR_HIGHV_VBUMP_SIUP_SIUP_VCCCLM_HIGHV_132110","IDV_0236_NOM3GNESFN712_FULLDIE_0950_MED_132110","TPI_VCC::CONT_PARALLEL_VLC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_SNR_ALL_VCCPAR_VLCDPS_VCCFUSE1_132110","TPI_VCC::CONT_VCCCLM_HC_E_START_X_X_X_X_POSTSURGE_CCMEAS_MIMS_VCCCLM_132110","TPI_VCC_X::CONT_PARALLEL_LC_E_START_X_X_X_X_MIMS_SNR_ALL_VCCPAR_LCDPS_VCCIOQ_132150","TPI_VCC::CONT_VCCVNN_HC_K_START_X_X_X_X_POSTSURGE_SNR_OLD_VCCVNN_132110"]
# X_test = X_test.drop(fs,axis=1)
X_test
# Out:
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSA_132110  \
# 0                                          0.419223
# 1                                          0.470038
# 2                                          0.372963
# 3                                          0.205177
# 4                                          0.202780
# ...                                             ...
# 35952                                      0.300575
# 35953                                      0.359779
# 35954                                      0.434084
# 35955                                      0.443912
# 35956                                      0.500000
#
#        IDV_0048_SVTNLK12_FULLDIE_SOC_0950_MED_132110  \
# 0                                           0.018470
# 1                                           0.026385
# 2                                           0.044855
# 3                                           0.031662
# 4                                           0.036939
# ...                                              ...
# 35952                                       0.071240
# 35953                                       0.036939
# 35954                                       0.058047
# 35955                                       0.094987
# 35956                                       0.050132
#
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSAC6S_132110  \
# 0                                             0.363026
# 1                                             0.321610
# 2                                             0.351226
# 3                                             0.265849
# 4                                             0.215872
# ...                                                ...
# 35952                                         0.218649
# 35953                                         0.138825
# 35954                                         0.248496
# 35955                                         0.278806
# 35956                                         0.462749
#
#        IDV_0148_SVTNLK12_FULLDIE_SOC_0950_MED_132110  \
# 0                                           0.160748
# 1                                           0.089720
# 2                                           0.213084
# 3                                           0.121495
# 4                                           0.190654
# ...                                              ...
# 35952                                       0.276636
# 35953                                       0.145794
# 35954                                       0.110280
# 35955                                       0.166355
# 35956                                       0.216822
#
#        TPI_VCC::CONT_VCCCOREM45_HC_K_START_X_X_X_X_POSTSURGE_SNR_OLD_VCCCORE_M45_132110  \
# 0                                               0.080766
# 1                                               0.070485
# 2                                               0.024095
# 3                                               0.031741
# 4                                               0.048415
# ...                                                  ...
# 35952                                           0.017830
# 35953                                           0.016674
# 35954                                           0.056735
# 35955                                           0.087159
# 35956                                           0.062165
#
#        TPI_VCC::CONT_PARALLEL_HC_E_FINAL_X_X_X_X_SNR_MIMS_SNR_ALL_VCCPAR_HCDPS_VCCINF_132110  \
# 0                                               0.043907
# 1                                               0.052880
# 2                                               0.006029
# 3                                               0.017274
# 4                                               0.039531
# ...                                                  ...
# 35952                                           0.011651
# 35953                                           0.005416
# 35954                                           0.031198
# 35955                                           0.060344
# 35956                                           0.038835
#
#        TPI_VCC_X::CONT_X_SCREEN_K_BEGIN_X_X_X_X_VCCADTL_VCCIN_EHV_LC_ADTL_132150  \
# 0                                               0.638453
# 1                                               0.601457
# 2                                               0.619955
# 3                                               0.645740
# 4                                               0.586697
# ...                                                  ...
# 35952                                           0.607810
# 35953                                           0.586510
# 35954                                           0.575673
# 35955                                           0.667040
# 35956                                           0.645179
#
#        TPI_VCC::CONT_PARALLEL_LC_E_FINAL_X_X_X_X_SNR_MIMS_SNR_ALL_VCCPAR_LCDPS_VCCAOPI_132110  \
# 0                                               0.063627
# 1                                               0.092261
# 2                                               0.010842
# 3                                               0.022250
# 4                                               0.054132
# ...                                                  ...
# 35952                                           0.022450
# 35953                                           0.008769
# 35954                                           0.042351
# 35955                                           0.073100
# 35956                                           0.076900
#
#        TPI_VCC::CONT_PARALLEL_HC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_SNR_ALL_VCCPAR_HCDPS_VCCINF_132110  \
# 0                                               0.046652
# 1                                               0.057338
# 2                                               0.009478
# 3                                               0.022722
# 4                                               0.040368
# ...                                                  ...
# 35952                                           0.013026
# 35953                                           0.006305
# 35954                                           0.037392
# 35955                                           0.063273
# 35956                                           0.038713
#
#        TPI_VCC::CONT_VCCCOREM23_HC_K_START_X_X_X_X_POSTSURGE_SNR_OLD_VCCCORE_M23_132110  \
# 0                                               0.081440
# 1                                               0.083120
# 2                                               0.019181
# 3                                               0.032912
# 4                                               0.061227
# ...                                                  ...
# 35952                                           0.029700
# 35953                                           0.029288
# 35954                                           0.055953
# 35955                                           0.090957
# 35956                                           0.054716
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 35952  ...
# 35953  ...
# 35954  ...
# 35955  ...
# 35956  ...
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_FBRK_N_CPU  \
# 0                                               0.250693
# 1                                               0.277271
# 2                                               0.159713
# 3                                               0.166869
# 4                                               0.124956
# ...                                                  ...
# 35952                                           0.092040
# 35953                                           0.080284
# 35954                                           0.106556
# 35955                                           0.075684
# 35956                                           0.080284
#
#        HVQK_VMIN_PRE_SCAN_UNCORE_SA_132110  \
# 0                                 0.229453
# 1                                 0.239466
# 2                                 0.395494
# 3                                 0.250313
# 4                                 0.250313
# ...                                    ...
# 35952                             0.396746
# 35953                             0.518148
# 35954                             0.250313
# 35955                             0.151439
# 35956                             0.422612
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSARMN2_132110  \
# 0                                           0.351301
# 1                                           0.486369
# 2                                           0.534696
# 3                                           0.322800
# 4                                           0.561958
# ...                                              ...
# 35952                                       0.568154
# 35953                                       0.858116
# 35954                                       0.407063
# 35955                                       0.265180
# 35956                                       0.473358
#
#        HVQK_VMIN_POST_SCAN_UNCORE_VNN_132110  \
# 0                                   0.321386
# 1                                   0.329263
# 2                                   0.450965
# 3                                   0.309571
# 4                                   0.382040
# ...                                      ...
# 35952                               0.465538
# 35953                               0.574242
# 35954                               0.281607
# 35955                               0.260339
# 35956                               0.407247
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132150_NAC_NET_CLK_REF1_P  \
# 0                                               0.079464
# 1                                               0.094196
# 2                                               0.258929
# 3                                               0.267857
# 4                                               0.150000
# ...                                                  ...
# 35952                                           0.069196
# 35953                                           0.141518
# 35954                                           0.133482
# 35955                                           0.240179
# 35956                                           0.140179
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_ERROR2_N_CPU  \
# 0                                               0.141322
# 1                                               0.152066
# 2                                               0.100000
# 3                                               0.100000
# 4                                               0.034711
# ...                                                  ...
# 35952                                           0.205785
# 35953                                           0.168595
# 35954                                           0.209917
# 35955                                           0.211570
# 35956                                           0.155372
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132150_NAC_CLK_SYNCE0_P  \
# 0                                               0.517910
# 1                                               0.497761
# 2                                               0.135821
# 3                                               0.188060
# 4                                               0.040448
# ...                                                  ...
# 35952                                           0.498507
# 35953                                           0.205224
# 35954                                           0.365672
# 35955                                           0.407463
# 35956                                           0.120149
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_NAC_KR23_DFTANA_0  \
# 0                                               0.046595
# 1                                               0.039068
# 2                                               0.069534
# 3                                               0.077778
# 4                                               0.094265
# ...                                                  ...
# 35952                                           0.010108
# 35953                                           0.023262
# 35954                                           0.016416
# 35955                                           0.003007
# 35956                                           0.031720
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_FIVR_PRB_DIG_1  \
# 0                                               0.223035
# 1                                               0.198355
# 2                                               0.236746
# 3                                               0.233090
# 4                                               0.233090
# ...                                                  ...
# 35952                                           0.138940
# 35953                                           0.161792
# 35954                                           0.110603
# 35955                                           0.190128
# 35956                                           0.180073
#
#        IDV_0001_SVT3GNES12_FULLDIE_SOC_0650_MED_132110
# 0                                             0.008473
# 1                                             0.008251
# 2                                             0.006188
# 3                                             0.010377
# 4                                             0.008060
# ...                                                ...
# 35952                                         0.006347
# 35953                                         0.004728
# 35954                                         0.010694
# 35955                                         0.012757
# 35956                                         0.008060
#
# [35957 rows x 300 columns]

# %%
# fs = ["TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCCORE_M01_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCFAD_GPIO_DTS_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05_SIUP_SICC_VCCAOPI_V1_132150","TPI_SIU_STATIC::SIU_STATIC_AM_K_START_X_X_X_SNR_VNOM_VCCINF_1P05
_X_X_X_X_SNR_MIMS_SNR_ALL_VCCPAR_LCDPS_VCCFAD_GPIO_DTS_132110","IDV_0120_NOMPDN12_FULLDIE_SOC_0950_MED_132110","TPI_VCC::CONT_PARALLEL_HC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_SNR_ALL_VCCPAR_HCDPS_VCCDDR_DQ_HV_132110","TPI_VCC::CONT_PARALLEL_VLC_E_FINAL_X_X_X_X_SNR_MIMS_SNR_ALL_VCCPAR_VLCDPS_VCCFUSE0_NAC_132110","TPI_VCC::CONT_PARALLEL_VLC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_SNR_ALL_VCCPAR_VLCDPS_VCCFUSE0_132110","TPI_VCC::CONT_VCCDDRDQ_HC_K_START_X_X_X_X_POSTSURGE_SNR_MIMS_VCCDDR_DQ_HV_132110","TPI_SIU_STATIC::SIU_STATIC_AM_K_STRESS_X_X_X_SNR_HIGHV_SIUP_SICC_VCCDDRA_HIGHV_132110","TPI_VCC::CONT_PARALLEL_VLC_E_FINAL_X_X_X_X_SNR_MIMS_SNR_ALL_VCCPAR_VLCDPS_VCCFUSE2_132110","TPI_SIU_STATIC::SIU_STATIC_AM_K_STRESS_X_X_X_SNR_HIGHV_VBUMP_SIUP_SIUP_VCCCLM_HIGHV_132110","IDV_0236_NOM3GNESFN712_FULLDIE_0950_MED_132110","TPI_VCC::CONT_PARALLEL_VLC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_SNR_ALL_VCCPAR_VLCDPS_VCCFUSE1_132110"]
# X_test = X_test.drop(fs,axis=1)
# print(X_test.shape)
# Out:
# (35957, 214)

# %%
# X_train_scaled = pd.read_csv(path + "/DataPreparation/MergedData_SameVID/TrainData_NegHandling.csv")
# y_train = X_train_scaled["SPECKLE"]
# X_train_scaled = X_train_scaled[X_test.columns]
# X_train_scaled

# %%
# # import the class
# from sklearn.svm import SVC

# # instantiate the model 
# model = SVC(C = 1, kernel = 'rbf', gamma='scale',class_weight= 'balanced',random_state=42)

# # fit the model with data
# model.fit(X_train_scaled,y_train)
# print(model)

# %%
#read model 
import joblib
model_path = path + 'ModelBuilding/MergedData_TrainValExchange_Na0/Ensemble300fs/SVM/Weight_6/'
model = joblib.load(model_path + 'SVMmodel.joblib')
print(model)
# Out:
# SVC(C=1, class_weight={0: 1, 1: 6}, random_state=42)

# %%
X_test
# Out:
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSA_132110  \
# 0                                          0.419223
# 1                                          0.470038
# 2                                          0.372963
# 3                                          0.205177
# 4                                          0.202780
# ...                                             ...
# 35952                                      0.300575
# 35953                                      0.359779
# 35954                                      0.434084
# 35955                                      0.443912
# 35956                                      0.500000
#
#        IDV_0048_SVTNLK12_FULLDIE_SOC_0950_MED_132110  \
# 0                                           0.018470
# 1                                           0.026385
# 2                                           0.044855
# 3                                           0.031662
# 4                                           0.036939
# ...                                              ...
# 35952                                       0.071240
# 35953                                       0.036939
# 35954                                       0.058047
# 35955                                       0.094987
# 35956                                       0.050132
#
#        HVQK_VMIN_POST_ARRAY_CORE_PBIST_L2SSAC6S_132110  \
# 0                                             0.363026
# 1                                             0.321610
# 2                                             0.351226
# 3                                             0.265849
# 4                                             0.215872
# ...                                                ...
# 35952                                         0.218649
# 35953                                         0.138825
# 35954                                         0.248496
# 35955                                         0.278806
# 35956                                         0.462749
#
#        IDV_0148_SVTNLK12_FULLDIE_SOC_0950_MED_132110  \
# 0                                           0.160748
# 1                                           0.089720
# 2                                           0.213084
# 3                                           0.121495
# 4                                           0.190654
# ...                                              ...
# 35952                                       0.276636
# 35953                                       0.145794
# 35954                                       0.110280
# 35955                                       0.166355
# 35956                                       0.216822
#
#        TPI_VCC::CONT_VCCCOREM45_HC_K_START_X_X_X_X_POSTSURGE_SNR_OLD_VCCCORE_M45_132110  \
# 0                                               0.080766
# 1                                               0.070485
# 2                                               0.024095
# 3                                               0.031741
# 4                                               0.048415
# ...                                                  ...
# 35952                                           0.017830
# 35953                                           0.016674
# 35954                                           0.056735
# 35955                                           0.087159
# 35956                                           0.062165
#
#        TPI_VCC::CONT_PARALLEL_HC_E_FINAL_X_X_X_X_SNR_MIMS_SNR_ALL_VCCPAR_HCDPS_VCCINF_132110  \
# 0                                               0.043907
# 1                                               0.052880
# 2                                               0.006029
# 3                                               0.017274
# 4                                               0.039531
# ...                                                  ...
# 35952                                           0.011651
# 35953                                           0.005416
# 35954                                           0.031198
# 35955                                           0.060344
# 35956                                           0.038835
#
#        TPI_VCC_X::CONT_X_SCREEN_K_BEGIN_X_X_X_X_VCCADTL_VCCIN_EHV_LC_ADTL_132150  \
# 0                                               0.638453
# 1                                               0.601457
# 2                                               0.619955
# 3                                               0.645740
# 4                                               0.586697
# ...                                                  ...
# 35952                                           0.607810
# 35953                                           0.586510
# 35954                                           0.575673
# 35955                                           0.667040
# 35956                                           0.645179
#
#        TPI_VCC::CONT_PARALLEL_LC_E_FINAL_X_X_X_X_SNR_MIMS_SNR_ALL_VCCPAR_LCDPS_VCCAOPI_132110  \
# 0                                               0.063627
# 1                                               0.092261
# 2                                               0.010842
# 3                                               0.022250
# 4                                               0.054132
# ...                                                  ...
# 35952                                           0.022450
# 35953                                           0.008769
# 35954                                           0.042351
# 35955                                           0.073100
# 35956                                           0.076900
#
#        TPI_VCC::CONT_PARALLEL_HC_E_START_X_X_X_X_POSTSURGE_SNR_MIMS_SNR_ALL_VCCPAR_HCDPS_VCCINF_132110  \
# 0                                               0.046652
# 1                                               0.057338
# 2                                               0.009478
# 3                                               0.022722
# 4                                               0.040368
# ...                                                  ...
# 35952                                           0.013026
# 35953                                           0.006305
# 35954                                           0.037392
# 35955                                           0.063273
# 35956                                           0.038713
#
#        TPI_VCC::CONT_VCCCOREM23_HC_K_START_X_X_X_X_POSTSURGE_SNR_OLD_VCCCORE_M23_132110  \
# 0                                               0.081440
# 1                                               0.083120
# 2                                               0.019181
# 3                                               0.032912
# 4                                               0.061227
# ...                                                  ...
# 35952                                           0.029700
# 35953                                           0.029288
# 35954                                           0.055953
# 35955                                           0.090957
# 35956                                           0.054716
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 35952  ...
# 35953  ...
# 35954  ...
# 35955  ...
# 35956  ...
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_FBRK_N_CPU  \
# 0                                               0.250693
# 1                                               0.277271
# 2                                               0.159713
# 3                                               0.166869
# 4                                               0.124956
# ...                                                  ...
# 35952                                           0.092040
# 35953                                           0.080284
# 35954                                           0.106556
# 35955                                           0.075684
# 35956                                           0.080284
#
#        HVQK_VMIN_PRE_SCAN_UNCORE_SA_132110  \
# 0                                 0.229453
# 1                                 0.239466
# 2                                 0.395494
# 3                                 0.250313
# 4                                 0.250313
# ...                                    ...
# 35952                             0.396746
# 35953                             0.518148
# 35954                             0.250313
# 35955                             0.151439
# 35956                             0.422612
#
#        HVQK_VMIN_POST_ARRAY_NAC_MBIST_LSARMN2_132110  \
# 0                                           0.351301
# 1                                           0.486369
# 2                                           0.534696
# 3                                           0.322800
# 4                                           0.561958
# ...                                              ...
# 35952                                       0.568154
# 35953                                       0.858116
# 35954                                       0.407063
# 35955                                       0.265180
# 35956                                       0.473358
#
#        HVQK_VMIN_POST_SCAN_UNCORE_VNN_132110  \
# 0                                   0.321386
# 1                                   0.329263
# 2                                   0.450965
# 3                                   0.309571
# 4                                   0.382040
# ...                                      ...
# 35952                               0.465538
# 35953                               0.574242
# 35954                               0.281607
# 35955                               0.260339
# 35956                               0.407247
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132150_NAC_NET_CLK_REF1_P  \
# 0                                               0.079464
# 1                                               0.094196
# 2                                               0.258929
# 3                                               0.267857
# 4                                               0.150000
# ...                                                  ...
# 35952                                           0.069196
# 35953                                           0.141518
# 35954                                           0.133482
# 35955                                           0.240179
# 35956                                           0.140179
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_ERROR2_N_CPU  \
# 0                                               0.141322
# 1                                               0.152066
# 2                                               0.100000
# 3                                               0.100000
# 4                                               0.034711
# ...                                                  ...
# 35952                                           0.205785
# 35953                                           0.168595
# 35954                                           0.209917
# 35955                                           0.211570
# 35956                                           0.155372
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132150_NAC_CLK_SYNCE0_P  \
# 0                                               0.517910
# 1                                               0.497761
# 2                                               0.135821
# 3                                               0.188060
# 4                                               0.040448
# ...                                                  ...
# 35952                                           0.498507
# 35953                                           0.205224
# 35954                                           0.365672
# 35955                                           0.407463
# 35956                                           0.120149
#
#        SIO_LKG_X::LO1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_NAC_KR23_DFTANA_0  \
# 0                                               0.046595
# 1                                               0.039068
# 2                                               0.069534
# 3                                               0.077778
# 4                                               0.094265
# ...                                                  ...
# 35952                                           0.010108
# 35953                                           0.023262
# 35954                                           0.016416
# 35955                                           0.003007
# 35956                                           0.031720
#
#        SIO_LKG_X::HI1P05_X_LKG_K_END_X_X_VMAX_X_1MA_PC1_132110_FIVR_PRB_DIG_1  \
# 0                                               0.223035
# 1                                               0.198355
# 2                                               0.236746
# 3                                               0.233090
# 4                                               0.233090
# ...                                                  ...
# 35952                                           0.138940
# 35953                                           0.161792
# 35954                                           0.110603
# 35955                                           0.190128
# 35956                                           0.180073
#
#        IDV_0001_SVT3GNES12_FULLDIE_SOC_0650_MED_132110
# 0                                             0.008473
# 1                                             0.008251
# 2                                             0.006188
# 3                                             0.010377
# 4                                             0.008060
# ...                                                ...
# 35952                                         0.006347
# 35953                                         0.004728
# 35954                                         0.010694
# 35955                                         0.012757
# 35956                                         0.008060
#
# [35957 rows x 300 columns]

# %%
#model testing
import joblib
import numpy as np
from sklearn import metrics

import os
model_path = model_path + 'Test/' 
if not os.path.exists(model_path):
    os.makedirs(model_path)

# Predicting the classes for validation set
y_pred = model.predict(X_test)

#overall accuracy
overall_acc = round(metrics.accuracy_score(y_test, y_pred)*100,2)
overall_acc = {'Overall Acc %':overall_acc}
overall_acc = pd.DataFrame([overall_acc])
overall_acc.to_csv(model_path+"Overall_Accuracy.csv")

#classification report
report = metrics.classification_report(y_test, y_pred,zero_division=0,output_dict=True)
report = pd.DataFrame(report).transpose()
report.to_csv(model_path+"Classification_Report.csv")

#confusion matrix with accuracies for each label
class_accuracies = []

for class_ in y_test.sort_values(ascending= True).unique():
    class_acc = round(np.mean(y_pred[y_test == class_] == class_)*100,2)
    class_accuracies.append(class_acc)
    
class_acc = pd.DataFrame(class_accuracies,index=['true:0', 'true:1'],columns= ["Accuracy %"])

cf_matrix = pd.DataFrame(
    metrics.confusion_matrix(y_test, y_pred, labels= [0, 1]), 
    index=['true:0', 'true:1'], 
    columns=['pred:0', 'pred:1']
)

ascend = None #input None/True/False to order the confusion matrix
if ascend == None:
    cf_matrix = pd.concat([cf_matrix,class_acc],axis=1)
else:
    cf_matrix = pd.concat([cf_matrix,class_acc],axis=1).sort_values(by=['Accuracy %'], ascending=ascend)

cf_matrix.to_csv(model_path+"Confusion_Matrix_test.csv")   
#confusion matrix with accuracies for each label

#validation results 
val_results = pd.concat([X_test_sf,X_test,pd.DataFrame(y_test),pd.DataFrame(y_pred,columns = ["PRED_SPECKLE"])],axis=1)
val_results.to_csv(model_path+"Val_results.csv",index=False)

# %%
Counter(y_pred)
# Out:
# Counter({0: 35917, 1: 40})

# %%
Counter(y_test)
# Out:
# Counter({0: 35866, 1: 91})

# %%
display(cf_matrix)
display(overall_acc)
display(report)
# Out:
#         pred:0  pred:1  Accuracy %
# true:0   35846      20       99.94
# true:1      71      20       21.98
#    Overall Acc %
# 0          99.75
#               precision    recall  f1-score       support
# 0              0.998023  0.999442  0.998732  35866.000000
# 1              0.500000  0.219780  0.305344     91.000000
# accuracy       0.997469  0.997469  0.997469      0.997469
# macro avg      0.749012  0.609611  0.652038  35957.000000
# weighted avg   0.996763  0.997469  0.996977  35957.000000
